# %% [markdown]
# # Scraping Infinite-Scroll Pada Anilist
#
# Infinite scrolling is a web-design technique that loads content continuously as the user scrolls down the page, eliminating the need for pagination. The success of infinite scrolling on social media sites such as Twitter
# [link](https://www.nngroup.com/articles/infinite-scrolling/)

# %%
from selenium import webdriver
import time

# %%
# Membuka Chrome Browser yang dikontrol oleh selenium
# Maximize Chrome Browser tersebut
# Bandingkan dengan PhantomJS
driver = webdriver.Chrome()

# %%
url = "https://anilist.co/search/anime?year=2020%25&season=WINTER"

# %%
driver.get(url)
print(driver.current_url)
driver.implicitly_wait(30)
# Out:
# https://anilist.co/search/anime?year=2020%25&season=WINTER

# %% [markdown]
# ### Analisa website anilist tersebut
#
# Lakukan scroll down page hingga habis lalu perhatikan apa yang terjadi pada website tersebut? item anime baru akan bermunculan beberapa detik kemudian.
#
# Bagaimana secara otomatis melakukan scroll down dengan selenium?
# Gunakan https://selenium-python.readthedocs.io/api.html#selenium.webdriver.remote.webdriver.WebDriver.execute_script untuk mengeksekusi perintah javascript https://developer.mozilla.org/en-US/docs/Web/API/Window/scrollTo
#
# ```js
# driver.execute_script('window.scrollTo(0, document.body.scrollHeight);')
# ```

# %% [markdown]
# ### Cara Scraping yang biasa dilakukan
#
# 1. Lihat struktur website yang akan diambil datanya seluruh info anime ada didalam tag div.media-card
# 2. Pada website anilist seluruh data tersusun rapi maka kita dapat mengambil cover, data, airing-countdown, extra, descriptions dan genres dengan mengambil classnya

# %%
results = driver.find_elements_by_class_name("media-card")

# %%
len(results)
# Out:
# 20

# %%
for anime in results:
    print(anime.text)
# Out:
# Haikyuu!! TO THE TOP
# Production I.G
# Ep 12 - 4d 11h 26m
# TV
# 84%
# The fourth season of Haikyuu!!
#
# The Karasuno High School Volleyball Club finally won their way into the nationals after an intense battle for the Miyagi Prefecture Spring Tournament qualifiers. As they were preparing for the nationals, Kageyama is invited to go to All-Japan Youth Training Camp. At the same time, Tsukishima is invited to go to a special rookie select training camp for first-years in Miyagi Prefecture. Hinata feels panic that he’s being left behind as one of the first-years and then decides to show up at the Miyagi Prefecture rookie select training camp anyway...
#
# (Source: Crunchyroll)
# Comedy , Drama , Sports
# Eizouken ni wa Te wo Dasu na!
# Science SARU
# Winter 2020
# TV
# 79%
# First year high schooler Midori Asakusa loves anime so much, she insists that "concept is everything" in animation. Though she draws a variety of ideas in her sketchbook, she hasn't taken the first step to creating anime, insisting that she can't do it alone. The producer-type Sayaka Kanamori is the first to notice Asakusa's genius. Then, when it becomes clear that their classmate, charismatic fashion model Tsubame Mizusaki, really wants to be an animator, they create an animation club to realize the "ultimate world" that exists in their minds.
#
# (Source: Crunchyroll)
# Adventure , Comedy
# Made in Abyss: Fukaki Tamashii no Reimei
# Kinema Citrus
# Winter 2020
# Movie
# 78%
# Dawn of the Deep Soul continues the epic adventure of plucky Riko and Reg who are joined by their new friend Nanachi. Together they descend into the Abyss’ treacherous fifth layer, the Sea of Corpses, and encounter the mysterious Bondrewd, a legendary White Whistle whose shadow looms over Nanachi’s troubled past. Bondrewd is ingratiatingly hospitable, but the brave adventurers know things are not always as they seem in the enigmatic Abyss...
# 70%
# Kaname Sudo, an ordinary high school student, receives an invitation email to try a mysterious app called "Darwin's Game." Kaname, upon launching the app, is drawn into a game where players fight one another using superpowers called Sigils.
#
# Without knowing the reason for all this, can Kaname survive furious battles against the powerful players who attack him?
#
# (Source: Aniplex of America)
# Action , Mystery
# BanG Dream! 3rd Season
# SANZIGEN
# Ep 9 - 3d 8h 31m
# TV
# 70%
# The third season of BanG Dream!
#
# The girl-powered bands are gigging again. That means Poppin’Party and other fan favorites are set to return for an all new season of BanG Dream! Now that Kasumi and the rest of Poppin’Party are taking charge of their own show, the sky’s the limit for their rockin’ musical ambitions and dreams of stardom. But they’ll have to contend with other bands looking for their big break, and their friendship will be put to the ultimate test as they rock their way to the top of the charts!
#
# (Source: Sentai Filmworks)
#
# Music , Slice of Life , Comedy
# Heya Camp△
# C-Station
# Ep 12 - 6h 56m
# TV Short
# 69%
# The Outdoor Activities Club, Aka, the Outclub has 3 members. In the countryside of Yamanashi Prefecture, there’s a high school named Motosu High School. Go even further to one of the school buildings and you’ll find a very laid-back outdoor club that uses one corner of the classroom as their club room. Kagamihara Nadeshiko finally wants to kill some time in their club room, but then Ohgaki Chiaki and Inuyama Aoi suddenly announce that they’re all going on a trip. The girls enjoy the various local treats as they travel around, but where in the world is the end destination for this trip?!
#
# (Source: Crunchyroll)
# Comedy , Slice of Life
# Goblin Slayer: GOBLIN'S CROWN
# White Fox
# Winter 2020
# Movie
# 68%
# A sequel movie to the TV series which adapts the 5th volume of the light novel.
# Action , Adventure , Fantasy
# Murenase! Seton Gakuen
# Studio Gokumi
# Ep 12 - 10h 31m
# TV
# 67%
# Seton Academy, a school where animals of all species gather to live and learn together. A sacred garden of learning, where students hone their primal instincts and the laws are of the jungle. Where species pit against species in a daily struggle for survival... Now enter the animal-hating human Jin Mazama, and the lonely wolf Ranka Okami. When man meets wolf in an encounter for the ages, this food chain is about to be shook. “Species shmecies! If we’ve shared face-licks, you’re a friend to me! Welcome to the pack!”
#
# (Source: Crunchyroll)
# Comedy , Ecchi , Romance

# %%
winter_anime = []

# %%
for anime in results:
    cover = anime.find_element_by_class_name("cover")
    extra = anime.find_element_by_class_name("extra").text.split("\n")
    genres = anime.find_element_by_class_name("genres").text
    c_text = cover.text.split("\n")
    winter_anime.append({
        'cover_title': c_text[0],
        'cover_studio': c_text[1],
        'cover_img': cover.get_attribute('data-src'),
        'format': extra[0],
        'duration': extra[1],
        'description': anime.find_element_by_class_name("description").text,
        'genres': genres.split(',')
    })

# %%
winter_anime
# Out:
# [{'cover_title': 'Haikyuu!! TO THE TOP',
#   'cover_studio': 'Production I.G',
#   'cover_img': 'https://s4.anilist.co/file/anilistcdn/media/anime/cover/large/bx106625-UR22wB2NuNVi.png',
#   'format': 'TV',
#   'duration': '84%',
#   'description': 'The fourth season of Haikyuu!!\n\nThe Karasuno High School Volleyball Club finally won their way into the nationals after an intense battle for the Miyagi Prefecture Spring Tournament qualifiers. As they were preparing for the nationals, Kageyama is invited to go to All-Japan Youth Training Camp. At the same time, Tsukishima is invited to go to a special rookie select training camp for first-years in Miyagi Prefecture. Hinata feels panic that he’s being left behind as one of the first-years and then decides to show up at the Miyagi Prefecture rookie select training camp anyway...\n\n(Source: Crunchyroll)',
#   'genres': ['Comedy ', ' Drama ', ' Sports']},
#  {'cover_title': 'Eizouken ni wa Te wo Dasu na!',
#   'cover_studio': 'Science SARU',
#   'cover_img': 'https://s4.anilist.co/file/anilistcdn/media/anime/cover/large/bx109298-YvjfI88hX76T.png',
#   'format': 'TV',
#   'duration': '79%',
#   'description': 'First year high schooler Midori Asakusa loves anime so much, she insists that "concept is everything" in animation. Though she draws a variety of ideas in her sketchbook, she hasn\'t taken the first step to creating anime, insisting that she can\'t do it alone. The producer-type Sayaka Kanamori is the first to notice Asakusa\'s genius. Then, when it becomes clear that their classmate, charismatic fashion model Tsubame Mizusaki, really wants to be an animator, they create an animation club to realize the "ultimate world" that exists in their minds.\n\n(Source: Crunchyroll)',
#   'genres': ['Adventure ', ' Comedy']},
#  {'cover_title': 'Made in Abyss: Fukaki Tamashii no Reimei',
#   'cover_studio': 'Kinema Citrus',
#   'cover_img': 'https://s4.anilist.co/file/anilistcdn/media/anime/cover/large/bx100643-fPH9OgEKKvcI.jpg',
#   'format': 'Movie',
#   'duration': '78%',
#   'description': 'Dawn of the Deep Soul continues the epic adventure of plucky Riko and Reg who are joined by their new friend Nanachi. Together they descend into the Abyss’ treacherous fifth layer, the Sea of Corpses, and encounter the mysterious Bondrewd, a legendary White Whistle whose shadow looms over Nanachi’s troubled past. Bondrewd is ingratiatingly hospitable, but the brave adventurers know things are not always as they seem in the enigmatic Abyss...\n\n(Source: Sentai Filmworks)',
#   'genres': ['Adventure ', ' Fantasy ', ' Sci-Fi ', ' Drama']},
#  {'cover_title': 'Haikyuu!! Riku VS Kuu',
#   'cover_studio': 'Production I.G',
#   'cover_img': 'https://s4.anilist.co/file/anilistcdn/media/anime/cover/large/bx111790-n5pkM1SYAqH2.png',
#   'format': 'OVA',
#   'duration': '78%',
#   'description': "First exhibited at Jump Festa 2020.\n\nIn the Miyagi Prefecture qualifiers for the Spring Tournament, Karasuno High School Volleyball Team manages to defeat Shiratorizawa Academy in an intense battle and secures their spot in the national tournament. Meanwhile in the Tokyo qualifiers, Nekoma High School, Fukurodani High School, Nohebi Academy, and Itachiyama Academy fight for the 3 slots to go to nationals.\n\nWill Nekoma High School be able to secure their spot in the tournament? Will we able to see a rematch of Nekoma and Karasuno's Battle of the Garbage Dump on a national level? The Tokyo qualifiers are about to begin!!\n\n(Source: Crunchyroll)",
#   'genres': ['Sports ', ' Drama ', ' Action ', ' Comedy']},
#  {'cover_title': 'Ishuzoku Reviewers',
#   'cover_studio': 'Passione',
#   'cover_img': 'https://s4.anilist.co/file/anilistcdn/media/anime/cover/large/bx110270-8xg2paEYcKZK.jpg',
#   'format': 'TV',
#   'duration': '76%',
#   'description': 'Beauty truly is in the eye of the beholder! From elves to succubi to cyclopes and more, the Yoruno Gloss reviewers are here to rate the red-light delights of all manner of monster girls...The only thing is, they can never agree on which species are the hottest!\n\n(Source: Yen Press)',
#   'genres': ['Comedy ', ' Ecchi ', ' Fantasy']},
#  {'cover_title': 'Toaru Kagaku no Railgun T',
#   'cover_studio': 'J.C. Staff',
#   'cover_img': 'https://s4.anilist.co/file/anilistcdn/media/anime/cover/large/bx104462-KrVWRvPcR7ci.jpg',
#   'format': 'TV',
#   'duration': '76%',
#   'description': 'The third season of Toaru Kagaku no Railgun.\n\nMisaka’s electro-manipulation abilities—and delightfully destructive Railgun projectile move—make her a rock star in Academy City. The techno-metropolis is packed with supernaturally powered students known as espers, including Misaka’s flirty friend and roommate, Kuroko. In this city full of super-powered gangs, mad scientists, and monsters—there’s no shortage of action!\n\n(Source: Crunchyroll)',
#   'genres': ['Action ', ' Sci-Fi']},
#  {'cover_title': 'Jibaku Shounen Hanako-kun',
#   'cover_studio': 'Lerche',
#   'cover_img': 'https://s4.anilist.co/file/anilistcdn/media/anime/cover/large/bx108463-knWkFUR311ho.jpg',
#   'format': 'TV',
#   'duration': '75%',
#   'description': '"Hanako-san, Hanako-san... are you there?"\n\nAt Kamome Academy, rumors abound about the school\'s Seven Mysteries, one of which is Hanako-san. Said to occupy the third stall of the third floor girls\' bathroom in the old school building, Hanako-san grants any wish when summoned. Nene Yashiro, an occult-loving high school girl who dreams of romance, ventures into this haunted bathroom... but the Hanako-san she meets there is nothing like she imagined! Kamome Academy\'s Hanako-san... is a boy!\n\n(Source: Yen Press)',
#   'genres': ['Comedy ', ' Supernatural']},
#  {'cover_title': 'ID: INVADED',
#   'cover_studio': 'NAZ',
#   'cover_img': 'https://s4.anilist.co/file/anilistcdn/media/anime/cover/large/bx110350-uchN78wglmhN.png',
#   'format': 'TV',
#   'duration': '74%',
#   'description': "Welcome to Kura, an organization that investigates crime using the Mizuhanome system which senses the drive to kill. Sakaido is a brilliant detective and pilot of the Mizuhanome. To solve a case, he enters the world of the killer's unconscious mind: the id well. In the shadows of brutal and puzzling cases lurks John Walker, the Serial Killer Creator. Where will Sakaido's pursuit lead?\n\n(Source: Funimation)",
#   'genres': ['Mystery ', ' Sci-Fi ', ' Psychological']},
#  {'cover_title': 'Dorohedoro',
#   'cover_studio': 'MAPPA',
#   'cover_img': 'https://s4.anilist.co/file/anilistcdn/media/anime/cover/large/bx105228-H4Ue718qFmpt.png',
#   'format': 'TV',
#   'duration': '74%',
#   'description': 'The story revolves around Kaiman, who does not remember who he was before he was transfigured by a Magic user. This transformation left him with a reptile\'s head, and a desire to find out the truth about who he really is. Accompanied by Nikaido, his female companion, he tracks down Magic Users in "The Hole" and unceremoniously chomps down on their head, hoping to find out who it was that put him in this state. One by one, they witness this "second man" inside the head of Kaiman, and after pulling them back out of his mouth he asks them all a question... "What did the guy inside my head say?"\n\n(Source: MangaUpdates)',
#   'genres': ['Action ', ' Adventure ', ' Fantasy ', ' Comedy ', ' Horror']},
#  {'cover_title': 'Somali to Mori no Kamisama',
#   'cover_studio': 'Satelight , HORNETS',
#   'cover_img': 'https://s4.anilist.co/file/anilistcdn/media/anime/cover/large/bx108617-PgoYLgWzzm0c.png',
#   'format': 'TV',
#   'duration': '74%',
#   'description': 'The first episode received an advance web distribution on January 3. The regular TV broadcast started on January 10.\n\nThe world is ruled by a diversity of inhuman beings, who persecuted humans and drove them to near-extinction. One day, the forest guardian Golem meets a human girl. This is a chronicle of a journey that would bind a member of the dying "human" clan to the forest guardian Golem, as father and daughter.\n\n(Source: Crunchyroll)',
#   'genres': ['Adventure ', ' Fantasy ', ' Slice of Life']},
#  {'cover_title': 'Itai no wa Iya nano de Bougyoryoku ni Kyokufuri Shitai to Omoimasu.',
#   'cover_studio': 'SILVER LINK.',
#   'cover_img': 'https://s4.anilist.co/file/anilistcdn/media/anime/cover/large/bx106479-JmPk1F5ubMtm.png',
#   'format': 'TV',
#   'duration': '73%',
#   'description': 'The story centers on Kaede Honjou, who is invited by her friend Risa Shiramine to play a virtual reality MMO game with her. While Kaede doesn\'t dislike games, what she really, truly dislikes is being in pain. She creates a character named Maple, and decides to put all her points in VIT to minimize pain. As a result, she moves slowly, can\'t use magic, and even a rabbit can get the best of her. However, as it turns out, she acquires a skill known as "Absolute Defense" as a result of her pumping points into VIT, as well as a "Counter Skill" that works against special moves. Now, with her ability to nullify all damage, she goes on adventures.\n\n(Source: Anime News Network, edited)',
#   'genres': ['Action ',
#    ' Adventure ',
#    ' Comedy ',
#    ' Fantasy ',
#    ' Slice of Life']},
#  {'cover_title': 'Rikei ga Koi ni Ochita no de Shoumei shitemita.',
#   'cover_studio': 'Zero-G',
#   'cover_img': 'https://s4.anilist.co/file/anilistcdn/media/anime/cover/large/bx107067-UOEanLoeuvYh.png',
#   'format': 'ONA',
#   'duration': '71%',
#   'description': 'Yukimura Shinya, and Himuro Ayame are two scientists that want to find out if love can be solved by a scientific theory. These two scientists also have feelings for each other and want to be able to solve their true feelings through similar theoretical facts. With this perfect opportunity, these scientists will attempt to solve the theory of the love they express for each other.\n\n(Source: MangaUpdates)',
#   'genres': ['Comedy ', ' Romance']},
#  {'cover_title': 'Isekai Quartet 2',
#   'cover_studio': 'Studio PuYUKAI',
#   'cover_img': 'https://s4.anilist.co/file/anilistcdn/media/anime/cover/large/bx110178-vaUatsXrfl2q.png',
#   'format': 'TV Short',
#   'duration': '71%',
#   'description': 'The second season of Isekai Quartet.',
#   'genres': ['Comedy ', ' Fantasy']},
#  {'cover_title': 'Runway de Waratte',
#   'cover_studio': 'Ezo’la',
#   'cover_img': 'https://s4.anilist.co/file/anilistcdn/media/anime/cover/large/bx111501-qZgcR8eb86t3.png',
#   'format': 'TV',
#   'duration': '70%',
#   'description': 'Chiyuki Fujito has a dream: to become a Paris Collection model. The problem is, she\'s too short to be a model, and everyone around her tells her so! But no matter what they say, she won\'t give up. Her classmate, a poor student named Ikuto Tsumura, also has a dream: to become a fashion designer. One day Chiyuki tells him that it\'s "probably impossible" for him, causing him to consider giving it up...?! This is the story of two individuals wholeheartedly chasing after their dreams in spite of all the negativity that comes after them!\n\n(Source: Kodansha Comics)',
#   'genres': ['Slice of Life ', ' Drama']},
#  {'cover_title': 'Kyokou Suiri',
#   'cover_studio': "Brain's Base",
#   'cover_img': 'https://s4.anilist.co/file/anilistcdn/media/anime/cover/large/bx107201-yT4iccdpBS1m.jpg',
#   'format': 'TV',
#   'duration': '70%',
#   'description': 'At the young age of 11, Kotoko Iwanaga was abducted by youkai for two weeks and asked to become their "God of Wisdom," a mediator between the spirit and human worlds, to which the girl quickly agreed but at the cost of her right eye and left leg. Now, six years later, whenever youkai wish for their problems to be solved, they make their way to Kotoko for consultation.\n\nMeanwhile, Kurou Sakuragawa, a 22-year-old university student, has just broken up with his girlfriend after he fled alone when the two encountered a kappa. Seeing this as her chance to become closer with him, Kotoko immediately makes her move, hoping to get married to Kurou one day. However, she quickly realizes there is something more to Kurou. With this knowledge, she asks for his help in solving the various issues presented by the supernatural, all the while wishing her newfound partner will eventually reciprocate her feelings.\n\n(Source: MyAnimeList)',
#   'genres': ['Comedy ',
#    ' Mystery ',
#    ' Supernatural ',
#    ' Romance ',
#    ' Horror']},
#  {'cover_title': "Darwin's Game",
#   'cover_studio': 'Nexus',
#   'cover_img': 'https://s4.anilist.co/file/anilistcdn/media/anime/cover/large/bx105190-1OG3lBqoIQ7o.png',
#   'format': 'TV',
#   'duration': '70%',
#   'description': 'Kaname Sudo, an ordinary high school student, receives an invitation email to try a mysterious app called "Darwin\'s Game." Kaname, upon launching the app, is drawn into a game where players fight one another using superpowers called Sigils.\n\nWithout knowing the reason for all this, can Kaname survive furious battles against the powerful players who attack him?\n\n(Source: Aniplex of America)',
#   'genres': ['Action ', ' Mystery']},
#  {'cover_title': 'BanG Dream! 3rd Season',
#   'cover_studio': 'SANZIGEN',
#   'cover_img': 'https://s4.anilist.co/file/anilistcdn/media/anime/cover/large/bx101634-4PSQAU2bw7s3.png',
#   'format': 'TV',
#   'duration': '70%',
#   'description': 'The third season of BanG Dream!\n\nThe girl-powered bands are gigging again. That means Poppin’Party and other fan favorites are set to return for an all new season of BanG Dream! Now that Kasumi and the rest of Poppin’Party are taking charge of their own show, the sky’s the limit for their rockin’ musical ambitions and dreams of stardom. But they’ll have to contend with other bands looking for their big break, and their friendship will be put to the ultimate test as they rock their way to the top of the charts!\n\n(Source: Sentai Filmworks)',
#   'genres': ['Music ', ' Slice of Life ', ' Comedy']},
#  {'cover_title': 'Heya Camp△',
#   'cover_studio': 'C-Station',
#   'cover_img': 'https://s4.anilist.co/file/anilistcdn/media/anime/cover/large/bx104461-rdwSQwNxFIyu.jpg',
#   'format': 'TV Short',
#   'duration': '69%',
#   'description': 'The Outdoor Activities Club, Aka, the Outclub has 3 members. In the countryside of Yamanashi Prefecture, there’s a high school named Motosu High School. Go even further to one of the school buildings and you’ll find a very laid-back outdoor club that uses one corner of the classroom as their club room. Kagamihara Nadeshiko finally wants to kill some time in their club room, but then Ohgaki Chiaki and Inuyama Aoi suddenly announce that they’re all going on a trip. The girls enjoy the various local treats as they travel around, but where in the world is the end destination for this trip?!\n\n(Source: Crunchyroll)',
#   'genres': ['Comedy ', ' Slice of Life']},
#  {'cover_title': "Goblin Slayer: GOBLIN'S CROWN",
#   'cover_studio': 'White Fox',
#   'cover_img': 'https://s4.anilist.co/file/anilistcdn/media/anime/cover/large/bx108623-pREPeutedpc2.jpg',
#   'format': 'Movie',
#   'duration': '68%',
#   'description': 'A sequel movie to the TV series which adapts the 5th volume of the light novel.',
#   'genres': ['Action ', ' Adventure ', ' Fantasy']},
#  {'cover_title': 'Murenase! Seton Gakuen',
#   'cover_studio': 'Studio Gokumi',
#   'cover_img': 'https://s4.anilist.co/file/anilistcdn/media/anime/cover/large/bx112293-UXFSGOfRbBe8.png',
#   'format': 'TV',
#   'duration': '67%',
#   'description': 'Seton Academy, a school where animals of all species gather to live and learn together. A sacred garden of learning, where students hone their primal instincts and the laws are of the jungle. Where species pit against species in a daily struggle for survival... Now enter the animal-hating human Jin Mazama, and the lonely wolf Ranka Okami. When man meets wolf in an encounter for the ages, this food chain is about to be shook. “Species shmecies! If we’ve shared face-licks, you’re a friend to me! Welcome to the pack!”\n\n(Source: Crunchyroll)',
#   'genres': ['Comedy ', ' Ecchi ', ' Romance']}]

# %% [markdown]
# ### Simpan Kedalam JSON

# %%
import json
f=open('ScrapingAnimelist.json','w')

# %%
json.dump(winter_anime,f)

# %%
f.close()

# %% [markdown]
# ### Cara Scraping Infinite Scroll (5 Page)

# %%
driver.get(url)
print(driver.current_url)
driver.implicitly_wait(30)
# Out:
# https://anilist.co/search/anime?year=2020%25&season=WINTER

# %%
for i in range(1, 5):
    driver.execute_script('window.scrollTo(0, document.body.scrollHeight);')
    # beri waktu jeda untuk load item anime
    # perhatikan perubahan di google chrome, halaman akan scroll down otomatis
    time.sleep(20)

# %%
results = driver.find_elements_by_class_name("media-card")
len(results)
# Out:
# 85

# %%
winter_anime = []

# %%
for anime in results:
    cover = anime.find_element_by_class_name("cover")
    extra = anime.find_element_by_class_name("extra").text.split("\n")
    genres = anime.find_element_by_class_name("genres").text
    c_text = cover.text.split("\n")
    winter_anime.append({
        'cover_title': c_text[0],
        'cover_studio': "" if len(c_text) < 2 else c_text[1],
        'cover_img': cover.get_attribute('data-src'),
        'format': extra[0],
        'duration': "" if len(extra) < 2 else extra[1],
        'description': anime.find_element_by_class_name("description").text,
        'genres': genres.split(',')
    })

# %%
winter_anime
# Out:
# [{'cover_title': 'Haikyuu!! TO THE TOP',
#   'cover_studio': 'Production I.G',
#   'cover_img': 'https://s4.anilist.co/file/anilistcdn/media/anime/cover/large/bx106625-UR22wB2NuNVi.png',
#   'format': 'TV',
#   'duration': '84%',
#   'description': 'The fourth season of Haikyuu!!\n\nThe Karasuno High School Volleyball Club finally won their way into the nationals after an intense battle for the Miyagi Prefecture Spring Tournament qualifiers. As they were preparing for the nationals, Kageyama is invited to go to All-Japan Youth Training Camp. At the same time, Tsukishima is invited to go to a special rookie select training camp for first-years in Miyagi Prefecture. Hinata feels panic that he’s being left behind as one of the first-years and then decides to show up at the Miyagi Prefecture rookie select training camp anyway...\n\n(Source: Crunchyroll)',
#   'genres': ['Comedy ', ' Drama ', ' Sports']},
#  {'cover_title': 'Eizouken ni wa Te wo Dasu na!',
#   'cover_studio': 'Science SARU',
#   'cover_img': 'https://s4.anilist.co/file/anilistcdn/media/anime/cover/large/bx109298-YvjfI88hX76T.png',
#   'format': 'TV',
#   'duration': '79%',
#   'description': 'First year high schooler Midori Asakusa loves anime so much, she insists that "concept is everything" in animation. Though she draws a variety of ideas in her sketchbook, she hasn\'t taken the first step to creating anime, insisting that she can\'t do it alone. The producer-type Sayaka Kanamori is the first to notice Asakusa\'s genius. Then, when it becomes clear that their classmate, charismatic fashion model Tsubame Mizusaki, really wants to be an animator, they create an animation club to realize the "ultimate world" that exists in their minds.\n\n(Source: Crunchyroll)',
#   'genres': ['Adventure ', ' Comedy']},
#  {'cover_title': 'Made in Abyss: Fukaki Tamashii no Reimei',
#   'cover_studio': 'Kinema Citrus',
#   'cover_img': 'https://s4.anilist.co/file/anilistcdn/media/anime/cover/large/bx100643-fPH9OgEKKvcI.jpg',
#   'format': 'Movie',
#   'duration': '78%',
#   'description': 'Dawn of the Deep Soul continues the epic adventure of plucky Riko and Reg who are joined by their new friend Nanachi. Together they descend into the Abyss’ treacherous fifth layer, the Sea of Corpses, and encounter the mysterious Bondrewd, a legendary White Whistle whose shadow looms over Nanachi’s troubled past. Bondrewd is ingratiatingly hospitable, but the brave adventurers know things are not always as they seem in the enigmatic Abyss...\n\n(Source: Sentai Filmworks)',
#   'genres': ['Adventure ', ' Fantasy ', ' Sci-Fi ', ' Drama']},
#  {'cover_title': 'Haikyuu!! Riku VS Kuu',
#   'cover_studio': 'Production I.G',
#   'cover_img': 'https://s4.anilist.co/file/anilistcdn/media/anime/cover/large/bx111790-n5pkM1SYAqH2.png',
#   'format': 'OVA',
#   'duration': '78%',
#   'description': "First exhibited at Jump Festa 2020.\n\nIn the Miyagi Prefecture qualifiers for the Spring Tournament, Karasuno High School Volleyball Team manages to defeat Shiratorizawa Academy in an intense battle and secures their spot in the national tournament. Meanwhile in the Tokyo qualifiers, Nekoma High School, Fukurodani High School, Nohebi Academy, and Itachiyama Academy fight for the 3 slots to go to nationals.\n\nWill Nekoma High School be able to secure their spot in the tournament? Will we able to see a rematch of Nekoma and Karasuno's Battle of the Garbage Dump on a national level? The Tokyo qualifiers are about to begin!!\n\n(Source: Crunchyroll)",
#   'genres': ['Sports ', ' Drama ', ' Action ', ' Comedy']},
#  {'cover_title': 'Ishuzoku Reviewers',
#   'cover_studio': 'Passione',
#   'cover_img': 'https://s4.anilist.co/file/anilistcdn/media/anime/cover/large/bx110270-8xg2paEYcKZK.jpg',
#   'format': 'TV',
#   'duration': '76%',
#   'description': 'Beauty truly is in the eye of the beholder! From elves to succubi to cyclopes and more, the Yoruno Gloss reviewers are here to rate the red-light delights of all manner of monster girls...The only thing is, they can never agree on which species are the hottest!\n\n(Source: Yen Press)',
#   'genres': ['Comedy ', ' Ecchi ', ' Fantasy']},
#  {'cover_title': 'Toaru Kagaku no Railgun T',
#   'cover_studio': 'J.C. Staff',
#   'cover_img': 'https://s4.anilist.co/file/anilistcdn/media/anime/cover/large/bx104462-KrVWRvPcR7ci.jpg',
#   'format': 'TV',
#   'duration': '76%',
#   'description': 'The third season of Toaru Kagaku no Railgun.\n\nMisaka’s electro-manipulation abilities—and delightfully destructive Railgun projectile move—make her a rock star in Academy City. The techno-metropolis is packed with supernaturally powered students known as espers, including Misaka’s flirty friend and roommate, Kuroko. In this city full of super-powered gangs, mad scientists, and monsters—there’s no shortage of action!\n\n(Source: Crunchyroll)',
#   'genres': ['Action ', ' Sci-Fi']},
#  {'cover_title': 'Jibaku Shounen Hanako-kun',
#   'cover_studio': 'Lerche',
#   'cover_img': 'https://s4.anilist.co/file/anilistcdn/media/anime/cover/large/bx108463-knWkFUR311ho.jpg',
#   'format': 'TV',
#   'duration': '75%',
#   'description': '"Hanako-san, Hanako-san... are you there?"\n\nAt Kamome Academy, rumors abound about the school\'s Seven Mysteries, one of which is Hanako-san. Said to occupy the third stall of the third floor girls\' bathroom in the old school building, Hanako-san grants any wish when summoned. Nene Yashiro, an occult-loving high school girl who dreams of romance, ventures into this haunted bathroom... but the Hanako-san she meets there is nothing like she imagined! Kamome Academy\'s Hanako-san... is a boy!\n\n(Source: Yen Press)',
#   'genres': ['Comedy ', ' Supernatural']},
#  {'cover_title': 'ID: INVADED',
#   'cover_studio': 'NAZ',
#   'cover_img': 'https://s4.anilist.co/file/anilistcdn/media/anime/cover/large/bx110350-uchN78wglmhN.png',
#   'format': 'TV',
#   'duration': '74%',
#   'description': "Welcome to Kura, an organization that investigates crime using the Mizuhanome system which senses the drive to kill. Sakaido is a brilliant detective and pilot of the Mizuhanome. To solve a case, he enters the world of the killer's unconscious mind: the id well. In the shadows of brutal and puzzling cases lurks John Walker, the Serial Killer Creator. Where will Sakaido's pursuit lead?\n\n(Source: Funimation)",
#   'genres': ['Mystery ', ' Sci-Fi ', ' Psychological']},
#  {'cover_title': 'Dorohedoro',
#   'cover_studio': 'MAPPA',
#   'cover_img': 'https://s4.anilist.co/file/anilistcdn/media/anime/cover/large/bx105228-H4Ue718qFmpt.png',
#   'format': 'TV',
#   'duration': '74%',
#   'description': 'The story revolves around Kaiman, who does not remember who he was before he was transfigured by a Magic user. This transformation left him with a reptile\'s head, and a desire to find out the truth about who he really is. Accompanied by Nikaido, his female companion, he tracks down Magic Users in "The Hole" and unceremoniously chomps down on their head, hoping to find out who it was that put him in this state. One by one, they witness this "second man" inside the head of Kaiman, and after pulling them back out of his mouth he asks them all a question... "What did the guy inside my head say?"\n\n(Source: MangaUpdates)',
#   'genres': ['Action ', ' Adventure ', ' Fantasy ', ' Comedy ', ' Horror']},
#  {'cover_title': 'Somali to Mori no Kamisama',
#   'cover_studio': 'Satelight , HORNETS',
#   'cover_img': 'https://s4.anilist.co/file/anilistcdn/media/anime/cover/large/bx108617-PgoYLgWzzm0c.png',
#   'format': 'TV',
#   'duration': '74%',
#   'description': 'The first episode received an advance web distribution on January 3. The regular TV broadcast started on January 10.\n\nThe world is ruled by a diversity of inhuman beings, who persecuted humans and drove them to near-extinction. One day, the forest guardian Golem meets a human girl. This is a chronicle of a journey that would bind a member of the dying "human" clan to the forest guardian Golem, as father and daughter.\n\n(Source: Crunchyroll)',
#   'genres': ['Adventure ', ' Fantasy ', ' Slice of Life']},
#  {'cover_title': 'Itai no wa Iya nano de Bougyoryoku ni Kyokufuri Shitai to Omoimasu.',
#   'cover_studio': 'SILVER LINK.',
#   'cover_img': 'https://s4.anilist.co/file/anilistcdn/media/anime/cover/large/bx106479-JmPk1F5ubMtm.png',
#   'format': 'TV',
#   'duration': '73%',
#   'description': 'The story centers on Kaede Honjou, who is invited by her friend Risa Shiramine to play a virtual reality MMO game with her. While Kaede doesn\'t dislike games, what she really, truly dislikes is being in pain. She creates a character named Maple, and decides to put all her points in VIT to minimize pain. As a result, she moves slowly, can\'t use magic, and even a rabbit can get the best of her. However, as it turns out, she acquires a skill known as "Absolute Defense" as a result of her pumping points into VIT, as well as a "Counter Skill" that works against special moves. Now, with her ability to nullify all damage, she goes on adventures.\n\n(Source: Anime News Network, edited)',
#   'genres': ['Action ',
#    ' Adventure ',
#    ' Comedy ',
#    ' Fantasy ',
#    ' Slice of Life']},
#  {'cover_title': 'Rikei ga Koi ni Ochita no de Shoumei shitemita.',
#   'cover_studio': 'Zero-G',
#   'cover_img': 'https://s4.anilist.co/file/anilistcdn/media/anime/cover/large/bx107067-UOEanLoeuvYh.png',
#   'format': 'ONA',
#   'duration': '71%',
#   'description': 'Yukimura Shinya, and Himuro Ayame are two scientists that want to find out if love can be solved by a scientific theory. These two scientists also have feelings for each other and want to be able to solve their true feelings through similar theoretical facts. With this perfect opportunity, these scientists will attempt to solve the theory of the love they express for each other.\n\n(Source: MangaUpdates)',
#   'genres': ['Comedy ', ' Romance']},
#  {'cover_title': 'Isekai Quartet 2',
#   'cover_studio': 'Studio PuYUKAI',
#   'cover_img': 'https://s4.anilist.co/file/anilistcdn/media/anime/cover/large/bx110178-vaUatsXrfl2q.png',
#   'format': 'TV Short',
#   'duration': '71%',
#   'description': 'The second season of Isekai Quartet.',
#   'genres': ['Comedy ', ' Fantasy']},
#  {'cover_title': 'Runway de Waratte',
#   'cover_studio': 'Ezo’la',
#   'cover_img': 'https://s4.anilist.co/file/anilistcdn/media/anime/cover/large/bx111501-qZgcR8eb86t3.png',
#   'format': 'TV',
#   'duration': '70%',
#   'description': 'Chiyuki Fujito has a dream: to become a Paris Collection model. The problem is, she\'s too short to be a model, and everyone around her tells her so! But no matter what they say, she won\'t give up. Her classmate, a poor student named Ikuto Tsumura, also has a dream: to become a fashion designer. One day Chiyuki tells him that it\'s "probably impossible" for him, causing him to consider giving it up...?! This is the story of two individuals wholeheartedly chasing after their dreams in spite of all the negativity that comes after them!\n\n(Source: Kodansha Comics)',
#   'genres': ['Slice of Life ', ' Drama']},
#  {'cover_title': 'Kyokou Suiri',
#   'cover_studio': "Brain's Base",
#   'cover_img': 'https://s4.anilist.co/file/anilistcdn/media/anime/cover/large/bx107201-yT4iccdpBS1m.jpg',
#   'format': 'TV',
#   'duration': '70%',
#   'description': 'At the young age of 11, Kotoko Iwanaga was abducted by youkai for two weeks and asked to become their "God of Wisdom," a mediator between the spirit and human worlds, to which the girl quickly agreed but at the cost of her right eye and left leg. Now, six years later, whenever youkai wish for their problems to be solved, they make their way to Kotoko for consultation.\n\nMeanwhile, Kurou Sakuragawa, a 22-year-old university student, has just broken up with his girlfriend after he fled alone when the two encountered a kappa. Seeing this as her chance to become closer with him, Kotoko immediately makes her move, hoping to get married to Kurou one day. However, she quickly realizes there is something more to Kurou. With this knowledge, she asks for his help in solving the various issues presented by the supernatural, all the while wishing her newfound partner will eventually reciprocate her feelings.\n\n(Source: MyAnimeList)',
#   'genres': ['Comedy ',
#    ' Mystery ',
#    ' Supernatural ',
#    ' Romance ',
#    ' Horror']},
#  {'cover_title': "Darwin's Game",
#   'cover_studio': 'Nexus',
#   'cover_img': 'https://s4.anilist.co/file/anilistcdn/media/anime/cover/large/bx105190-1OG3lBqoIQ7o.png',
#   'format': 'TV',
#   'duration': '70%',
#   'description': 'Kaname Sudo, an ordinary high school student, receives an invitation email to try a mysterious app called "Darwin\'s Game." Kaname, upon launching the app, is drawn into a game where players fight one another using superpowers called Sigils.\n\nWithout knowing the reason for all this, can Kaname survive furious battles against the powerful players who attack him?\n\n(Source: Aniplex of America)',
#   'genres': ['Action ', ' Mystery']},
#  {'cover_title': 'BanG Dream! 3rd Season',
#   'cover_studio': 'SANZIGEN',
#   'cover_img': 'https://s4.anilist.co/file/anilistcdn/media/anime/cover/large/bx101634-4PSQAU2bw7s3.png',
#   'format': 'TV',
#   'duration': '70%',
#   'description': 'The third season of BanG Dream!\n\nThe girl-powered bands are gigging again. That means Poppin’Party and other fan favorites are set to return for an all new season of BanG Dream! Now that Kasumi and the rest of Poppin’Party are taking charge of their own show, the sky’s the limit for their rockin’ musical ambitions and dreams of stardom. But they’ll have to contend with other bands looking for their big break, and their friendship will be put to the ultimate test as they rock their way to the top of the charts!\n\n(Source: Sentai Filmworks)',
#   'genres': ['Music ', ' Slice of Life ', ' Comedy']},
#  {'cover_title': 'Heya Camp△',
#   'cover_studio': 'C-Station',
#   'cover_img': 'https://s4.anilist.co/file/anilistcdn/media/anime/cover/large/bx104461-rdwSQwNxFIyu.jpg',
#   'format': 'TV Short',
#   'duration': '69%',
#   'description': 'The Outdoor Activities Club, Aka, the Outclub has 3 members. In the countryside of Yamanashi Prefecture, there’s a high school named Motosu High School. Go even further to one of the school buildings and you’ll find a very laid-back outdoor club that uses one corner of the classroom as their club room. Kagamihara Nadeshiko finally wants to kill some time in their club room, but then Ohgaki Chiaki and Inuyama Aoi suddenly announce that they’re all going on a trip. The girls enjoy the various local treats as they travel around, but where in the world is the end destination for this trip?!\n\n(Source: Crunchyroll)',
#   'genres': ['Comedy ', ' Slice of Life']},
#  {'cover_title': "Goblin Slayer: GOBLIN'S CROWN",
#   'cover_studio': 'White Fox',
#   'cover_img': 'https://s4.anilist.co/file/anilistcdn/media/anime/cover/large/bx108623-pREPeutedpc2.jpg',
#   'format': 'Movie',
#   'duration': '68%',
#   'description': 'A sequel movie to the TV series which adapts the 5th volume of the light novel.',
#   'genres': ['Action ', ' Adventure ', ' Fantasy']},
#  {'cover_title': 'Murenase! Seton Gakuen',
#   'cover_studio': 'Studio Gokumi',
#   'cover_img': 'https://s4.anilist.co/file/anilistcdn/media/anime/cover/large/bx112293-UXFSGOfRbBe8.png',
#   'format': 'TV',
#   'duration': '67%',
#   'description': 'Seton Academy, a school where animals of all species gather to live and learn together. A sacred garden of learning, where students hone their primal instincts and the laws are of the jungle. Where species pit against species in a daily struggle for survival... Now enter the animal-hating human Jin Mazama, and the lonely wolf Ranka Okami. When man meets wolf in an encounter for the ages, this food chain is about to be shook. “Species shmecies! If we’ve shared face-licks, you’re a friend to me! Welcome to the pack!”\n\n(Source: Crunchyroll)',
#   'genres': ['Comedy ', ' Ecchi ', ' Romance']},
#  {'cover_title': 'Magia Record: Mahou Shoujo Madoka☆Magica Gaiden',
#   'cover_studio': 'Shaft',
#   'cover_img': 'https://s4.anilist.co/file/anilistcdn/media/anime/cover/large/bx104051-tFMIbiffwBLs.jpg',
#   'format': 'TV',
#   'duration': '67%',
#   'description': 'A dream of an unknown girl beckons Iroha Tamaki to Kamihama City, a mysterious place where Magical Girls gather and Witches of unimaginable strength proliferate. A new power drawn from evil Witches is on the rise, and as the mysteries of Kamihama begin to come to light, Iroha is sure of one thing only: understanding the secrets of Kamihama is the key to unlocking the identity of the enigmatic — and inexplicably familiar — girl in her dreams.\n\n(Source: HIDIVE)',
#   'genres': ['Drama ', ' Mahou Shoujo ', ' Psychological ', ' Thriller']},
#  {'cover_title': 'Oshi ga Budoukan Ittekuretara Shinu',
#   'cover_studio': '8-bit',
#   'cover_img': 'https://s4.anilist.co/file/anilistcdn/media/anime/cover/large/bx104391-5gOoFEMiSFg1.png',
#   'format': 'TV',
#   'duration': '67%',
#   'description': 'Eripiyo is an extreme idol fan. She is wildly enthusiastic about Maina, the shy and lowest-ranking member of the minor underground idol group ChamJam that performs in Okayama Prefecture. Eri will continue to give her complete devotion to Maina until the day she can perform at Budokan.\n\n(Source: Anime News Network, edited)',
#   'genres': ['Music ', ' Comedy']},
#  {'cover_title': 'Hakumei no Tsubasa',
#   'cover_studio': 'Studio Colorido',
#   'cover_img': 'https://s4.anilist.co/file/anilistcdn/media/anime/cover/large/bx113932-UcnzFguKFy6D.jpg',
#   'format': 'ONA',
#   'duration': '66%',
#   'description': 'The anime will be an "ensemble drama" showing the struggles and conflicts of young people living in the Galar region.',
#   'genres': ['Action ',
#    ' Adventure ',
#    ' Comedy ',
#    ' Fantasy ',
#    ' Slice of Life']},
#  {'cover_title': 'Koisuru Asteroid',
#   'cover_studio': 'Doga Kobo',
#   'cover_img': 'https://s4.anilist.co/file/anilistcdn/media/anime/cover/large/bx108092-vbL3rf0b23sp.jpg',
#   'format': 'TV',
#   'duration': '65%',
#   'description': "When she was little, Konohata Mira promises a boy she meets at a campsite that they can find a galaxy together. When she enters high school, she joins the astronomy club. But that year, the astronomy club happened to combine with the geology club, making it the astrogeo club?!\n\nWon't you find all kinds of sparkles with the astrogeo girls?\n\n(Source: Crunchyroll)",
#   'genres': ['Comedy ', ' Slice of Life']},
#  {'cover_title': 'ACCA: 13-ku Kansatsu-ka - Regards',
#   'cover_studio': 'MADHOUSE',
#   'cover_img': 'https://s4.anilist.co/file/anilistcdn/media/anime/cover/large/bx108714-7QDTectcCIa3.jpg',
#   'format': 'OVA',
#   'duration': '64%',
#   'description': "The special's story is set in the capital city of Badon one year after the events of the television anime, and shows Jean and the rest of the ACCA department preparing for the one-year anniversary of the establishment of the new order. For the characters — caught between rumors of unrest, unchanging days, new crossroads, gazes remembered in memories, and days of new beginnings — time once again begins to move forward.\n\n(Source: Anime News Network)",
#   'genres': ['Drama ', ' Mystery']},
#  {'cover_title': 'Kuutei Dragons',
#   'cover_studio': 'POLYGON PICTURES',
#   'cover_img': 'https://s4.anilist.co/file/anilistcdn/media/anime/cover/large/bx108450-egUEb5lOpGxS.jpg',
#   'format': 'ONA',
#   'duration': '64%',
#   'description': "It's time to see what dragon tastes like. The crew of the airship Queen Zaza makes their living hunting dragons. Succeed, and the reward is riches and all the meat they can eat! Fail, and all that awaits them is a messy end. Follow the grand hunting and cooking adventure of the Queen Zaza as they chase dragons across the sky.\n\nAll episodes premiered on Netflix on January 9, but aired weekly on TV.",
#   'genres': ['Fantasy ', ' Action ', ' Adventure']},
#  {'cover_title': 'Nekopara',
#   'cover_studio': 'Felix Film',
#   'cover_img': 'https://s4.anilist.co/file/anilistcdn/media/anime/cover/large/bx106863-CxiCK7HejySK.png',
#   'format': 'TV',
#   'duration': '62%',
#   'description': "In this world, cats aren't furry four-footed creatures, but human-like girls with ears, tails, and cat-like behaviors. Still kept as pets, they're allowed out on their own if they pass a special training and wear their bells. A young man running his own patisserie lives with two of these cats, Chocola and Vanilla, who help him out around the store. Maple and Cinnamon, two of the cats from home, also come in everyday, and together they enjoy a sweet life. Even if the cats don't always get along – and Azuki and Coconut certainly don't – things are peaceful and calm until a stray kitten follows Chocola home.\n\n(Source: Anime News Network)",
#   'genres': ['Comedy ', ' Romance ', ' Slice of Life ', ' Ecchi']},
#  {'cover_title': 'Mushikago no Cagaster',
#   'cover_studio': 'Studio Kai',
#   'cover_img': 'https://s4.anilist.co/file/anilistcdn/media/anime/cover/large/bx109586-N6FtjTtCWB4G.jpg',
#   'format': 'ONA',
#   'duration': '62%',
#   'description': 'In a near future, an illness called "Cagaster" made its appearance. It turns humans into insects. The story begins 30 years after the onset of the illness, in 2125. It follows the adventures of Kidou, a boy who fights insects.',
#   'genres': ['Action ', ' Drama ', ' Sci-Fi']},
#  {'cover_title': '22/7',
#   'cover_studio': 'A-1 Pictures',
#   'cover_img': 'https://s4.anilist.co/file/anilistcdn/media/anime/cover/large/bx99807-bkaSfYalAcbf.jpg',
#   'format': 'TV',
#   'duration': '61%',
#   'description': 'One day, Miu Takigawa suddenly receives a letter notifying her that she has been chosen as a member of a brand-new project. Half in disbelief, she heads over to the location stated on the letter. There, she finds seven other girls summoned there in the same fashion. The girls behold a giant, top-secret facility. They stand in bewilderment as they are told:\n\n"You are going to debut for a major record label as an idol group."\n\nA new kind of idol, never-before-seen, is about to be born here…\n\n(Source: Aniplex of America)',
#   'genres': ['Music ', ' Drama']},
#  {'cover_title': "Healin' Good ♥ Precure",
#   'cover_studio': 'Toei Animation',
#   'cover_img': 'https://s4.anilist.co/file/anilistcdn/media/anime/cover/large/bx112748-TkfRFNCgQFQX.jpg',
#   'format': 'TV',
#   'duration': '61%',
#   'description': 'Deep inside the Earth lies a magical place called the "Healing Garden", which cared for the planet for centuries and is been protected by animal-like fairies named "Healing Animals". However, the garden was attacked by the antagonistic group called Bjögens whose goal is to infect the garden and slowly poison the planet. In order to save the Healing Garden, Latte escaped to the human world alongside three "medical trainee" Healing Animals, on a mission to find three people who can partner with them. After they meet Nodoka, Chiyu and Hinata, Latte pleaded them to fight for the Healing Garden as they became Pretty Cures in order to fight against the threat of the Bjögens and protect all life on Earth and the Healing Garden.\n\n(Source: Wikipedia)',
#   'genres': ['Mahou Shoujo']},
#  {'cover_title': 'Housekishou Richard-shi no Nazo Kantei',
#   'cover_studio': 'Studio Shuka',
#   'cover_img': 'https://s4.anilist.co/file/anilistcdn/media/anime/cover/large/bx111951-vzX8hv9fl9pR.png',
#   'format': 'TV',
#   'duration': '60%',
#   'description': "The 'heartwarming jewel mystery' series centers on the handsome jewelry appraiser Richard Ranashinha de Vulpian and the bright and cheerful college student Seigi Nakata as they uncover the hidden messages that lie within jewels while they solve various jewel-related cases by unravelling the hidden psychological aspects of their owners that lie within the gems.\n\n(Source: Anime News Network, Edited)",
#   'genres': ['Mystery']},
#  {'cover_title': 'Dungeon ni Deai wo Motomeru no wa Machigatteiru Darou ka II OVA',
#   'cover_studio': 'J.C. Staff',
#   'cover_img': 'https://s4.anilist.co/file/anilistcdn/media/anime/cover/large/bx112125-iho4D7GD13at.jpg',
#   'format': 'OVA',
#   'duration': '60%',
#   'description': 'Bell and the gang found themselves in a hot spring at the end of their last adventure, and this time they’re ready for a little R&R at the beach! Hestia, Lili and Haruhime waste no time trying to win Bell over with their charms and run into unexpected competition once Ais crashes the party. However, the usually stoic sword maiden is acting surprisingly carefree...\n\n(Source: Sentai Filmworks)',
#   'genres': ['Comedy ', ' Adventure ', ' Fantasy ', ' Romance ', ' Ecchi']},
#  {'cover_title': 'Strike the Blood: Kieta Seisou-hen',
#   'cover_studio': 'CONNECT',
#   'cover_img': 'https://s4.anilist.co/file/anilistcdn/media/anime/cover/large/bx112324-RM9uxYAFhi3c.jpg',
#   'format': 'OVA',
#   'duration': '60%',
#   'description': '',
#   'genres': ['Action ', ' Ecchi ', ' Fantasy ', ' Supernatural']},
#  {'cover_title': 'Uchitama?! Uchi no Tama Shirimasenka?',
#   'cover_studio': 'MAPPA , Lapin Track',
#   'cover_img': 'https://s4.anilist.co/file/anilistcdn/media/anime/cover/large/bx109964-WLzxb4UNBJxM.png',
#   'format': 'TV',
#   'duration': '60%',
#   'description': 'Spin-off of "Tama and Friends" that reimagines the cast of the franchise as humans.\n\n“Tama & Friends: Have you seen my Tama?” debuted in 1983 as a popular character on stationery and accessories. Tama, the beloved neighborhood cat who is known for the patch on his forehead and yellow ears, has now taken on a human form! Featuring Tama and his quirky friends, Uchitama is a brand-new type of heartwarming anime that might even be the new definition of kawaii!?\n\nIn a city somewhere in Japan, there\'s a flyer often seen on Third Street with a picture of a cat with a kinked tail, bearing the words: “Have you seen Tama?” A young boy gazes at the flyer, but he has fluffy ears on his head…!? Watch the dogs and cats from Third Street take on a human form and get up to some mischief.\n\nTake a peek into the wonderful lives of Tama and his friends.\n\n(Source: Aniplex of America)',
#   'genres': ['Slice of Life ', ' Comedy']},
#  {'cover_title': 'Show By Rock!! Mashumairesh!!',
#   'cover_studio': 'Kinema Citrus',
#   'cover_img': 'https://s4.anilist.co/file/anilistcdn/media/anime/cover/large/bx113470-Ecw16VC6b2V2.jpg',
#   'format': 'TV',
#   'duration': '59%',
#   'description': 'The new anime will center around the band Mashumairesh!!!!, which includes guitarist and vocalist Howan of fox lineage, guitarist and vocalist MashimaHimeko of striped cat lineage, bassist and vocalist Delmin of the Devilmint Kiryuu lineage, and drummer and vocalist Ruhuyu of wolf-girl lineage.\n\n(Source: Anime News Network)',
#   'genres': ['Music']},
#  {'cover_title': 'Tsugumomo OVA',
#   'cover_studio': 'Zero-G',
#   'cover_img': 'https://s4.anilist.co/file/anilistcdn/media/anime/cover/large/bx108267-DDt0rqIc0xeg.jpg',
#   'format': 'OVA',
#   'duration': '59%',
#   'description': '',
#   'genres': ['Action ', ' Comedy ', ' Ecchi ', ' Supernatural']},
#  {'cover_title': 'Altered Carbon: Resleeved',
#   'cover_studio': 'Studio Anima',
#   'cover_img': 'https://s4.anilist.co/file/anilistcdn/media/anime/cover/large/bx115715-K5yG9XQ8kHsq.jpg',
#   'format': 'ONA',
#   'duration': '59%',
#   'description': "Spin-off based on Netflix's live-action Sci-Fi series of the same name.\n\nOn the planet Latimer, Takeshi Kovacs must protect a tattooist while investigating the death of a yakuza boss alongside a no-nonsense CTAC.\n\n(Source: Netflix)",
#   'genres': ['Action ', ' Drama ', ' Sci-Fi']},
#  {'cover_title': 'Yatogame-chan Kansatsu Nikki 2 Satsume',
#   'cover_studio': '',
#   'cover_img': 'https://s4.anilist.co/file/anilistcdn/media/anime/cover/large/bx110090-g1mRz40rSSqh.jpg',
#   'format': 'TV Short',
#   'duration': '58%',
#   'description': 'The second season of Yatogame-chan Kansatsu Nikki.',
#   'genres': ['Comedy ', ' Slice of Life']},
#  {'cover_title': 'Plunderer',
#   'cover_studio': 'Geek Toys',
#   'cover_img': 'https://s4.anilist.co/file/anilistcdn/media/anime/cover/large/bx101168-7bmHkVlFxBCS.png',
#   'format': 'TV',
#   'duration': '57%',
#   'description': 'Every human inhabiting the world of Alcia is branded by a “Count” or a number written on their body. Depending on how each person lives their life, this Count either goes up or down. For Hina’s mother, her total drops to 0 and she’s pulled into the Abyss, never to be seen again. But her mother’s last words send Hina on a quest to find a legendary hero from the Waste War—the fabled Ace!\n\n(Source: Funimation)',
#   'genres': ['Action ',
#    ' Adventure ',
#    ' Comedy ',
#    ' Drama ',
#    ' Ecchi ',
#    ' Fantasy ',
#    ' Romance']},
#  {'cover_title': 'pet',
#   'cover_studio': 'Geno Studio',
#   'cover_img': 'https://s4.anilist.co/file/anilistcdn/media/anime/cover/large/bx101350-nRjxYT3r6qTC.jpg',
#   'format': 'TV',
#   'duration': '57%',
#   'description': 'The psychic suspense story revolves around people who possess the ability to infiltrate people\'s minds and manipulate memories. Their powers have been used in the underworld for covering up incidents, assassinations, and other deeds. These powers can not only destroy other people\'s spirits, but also corrupt the users\' own hearts at the same time. The users had to protect their fragile and insecure hearts, as if chained to each other. They are called "pets" out of fear and despising.\n\n(Source: Anime News Network)',
#   'genres': ['Supernatural ', ' Psychological ', ' Drama']},
#  {'cover_title': 'Infinite Dendrogram',
#   'cover_studio': 'NAZ',
#   'cover_img': 'https://s4.anilist.co/file/anilistcdn/media/anime/cover/large/bx107420-fTC53wOorIsl.jpg',
#   'format': 'TV',
#   'duration': '57%',
#   'description': "In the year 2043, Infinite Dendrogram, the world's first successful full-dive VRMMO was released. In addition to its ability to perfectly simulate the five senses, along with its many other amazing features, the game promised to offer players a world full of infinite possibilities.\n\nNearly two years later, soon-to-be college freshman, Reiji Mukudori, is finally able to buy a copy of the game and start playing. With some help from his experienced older brother, Shuu, and his partner Embryo, Reiji embarks on an adventure into the world of Infinite Dendrogram. Just what will he discover and encounter in this game world known for its incredible realism and infinite possibilities?\n\n(Source: J-Novel Club)",
#   'genres': ['Sci-Fi ', ' Action ', ' Fantasy ', ' Adventure']},
#  {'cover_title': 'number24',
#   'cover_studio': 'PRA',
#   'cover_img': 'https://s4.anilist.co/file/anilistcdn/media/anime/cover/large/bx108628-TmkHwStCyOoX.png',
#   'format': 'TV',
#   'duration': '55%',
#   'description': "The anime's college rugby story centers on Natsusa Yuzuki, who expects to be an ace on the rugby team when he enrolls in college. However, he is no longer able to play rugby due to certain circumstances. Ibuki Ueoka is an older fellow student who quit rugby. Yasunari Tsuru is a younger student who finds Natsusa disagreeable. Yuu Mashiro is a younger student who admires and follows Natsusa. Seiichirou Shingyou is Natsusa's close childhood friend. Together, they compete in the Kansai university rugby league.\n\n(Source: Anime News Network)",
#   'genres': ['Sports']},
#  {'cover_title': 'A3! SEASON SPRING ＆ SUMMER',
#   'cover_studio': 'Studio 3Hz , P.A. Works',
#   'cover_img': 'https://s4.anilist.co/file/anilistcdn/media/anime/cover/large/bx107651-GYi8XSIHW0pG.png',
#   'format': 'TV',
#   'duration': '55%',
#   'description': 'Mankai Company is a far cry from its glory days as an all-male theater. With only one member left and debt collectors at the door, it’s no wonder Izumi Tachibana finds herself in over her head when she boldly confronts the yakuza’s loan sharks, promising to bring her father’s theater back into the spotlight. She might be able to recruit enough talent, but can they bloom into the actors she needs?\n\n(Source: Funimation)',
#   'genres': ['Music ', ' Drama']},
#  {'cover_title': 'Boku no Tonari ni Ankoku Hakaishin ga Imasu.',
#   'cover_studio': 'EMT Squared',
#   'cover_img': 'https://s4.anilist.co/file/anilistcdn/media/anime/cover/large/bx104936-pj2LwAKTPZ4u.png',
#   'format': 'TV',
#   'duration': '55%',
#   'description': 'Seri Koyuki is just trying to have a normal school life, but instead he ends up acting as the straight man to his odd classmate, Kabuto Hanadori. Kabuto is is a delusional high school student, whose fantasies range from believing he is a knight on a journey, to claiming that removing his eyepatch will release a darker alter-ego who he refers to as Michael Offenbarung Dunkelheit. Seri is determined not to let himself get pushed around by Kabuto, but it seems that this will be easier said than done!',
#   'genres': ['Comedy ', ' Slice of Life']},
#  {'cover_title': 'Natsunagu!',
#   'cover_studio': 'Imagica Lab.',
#   'cover_img': 'https://s4.anilist.co/file/anilistcdn/media/anime/cover/large/bx113397-Js0fp84kcgiS.png',
#   'format': 'TV Short',
#   'duration': '54%',
#   'description': 'The story follows the coming-of-age of Natsuna Keyaki, a college student from Tokyo who goes to Kumamoto after losing contact with her friend after the 2016 earthquakes. There, she meets individuals with colorful personalities, such as middle school girl Izumi, who begin to light a passion in Natsuna.\n\n(Source: Anime News Network, edited)',
#   'genres': ['Drama ', ' Slice of Life']},
#  {'cover_title': 'Majutsushi Orphen Hagure Tabi',
#   'cover_studio': 'Studio DEEN',
#   'cover_img': 'https://s4.anilist.co/file/anilistcdn/media/anime/cover/large/bx101367-ISegytCr3Azy.jpg',
#   'format': 'TV',
#   'duration': '53%',
#   'description': "A remake of the original 1998-1999 anime of the same name, to commemorate the novels' 25th anniversary.\n\nOrphen is the greatest sorcerer that the tower has ever seen but he is more interested in chasing the Bloody August, an infamous and very mysterious dragon. Along with his apprentice Majic and their companion Clio he heads off on a quest with the Sword of Baltanders, the only thing that can free the Bloody August or 'Azile' from the spell she is under.\n\n(Source: Anime News Network)",
#   'genres': ['Action ', ' Fantasy ', ' Adventure']},
#  {'cover_title': 'Zenonzard THE ANIMATION',
#   'cover_studio': '8-bit',
#   'cover_img': 'https://s4.anilist.co/file/anilistcdn/media/anime/cover/large/bx112033-OJCATuZi1FGz.png',
#   'format': 'ONA',
#   'duration': '52%',
#   'description': 'The year 20XX. Humans called "Concodes" and ultra-high-performance AI called "Codeman" team up as buddies to compete in the card battle game ZENONZARD. People are going wild with excitement at the world championships, THE ZENON.\n\nOne day, Souta Azuma, an average high school student, is challenged to a battle by a mysterious woman, Eilietta Lash. She reveals that she’s a Codeman and that her intent is to team up with Souta and participate in THE ZENON. Souta reluctantly agrees. Souta and Eilietta’s first opponent turns out to be the super-famous player Shion Saionji, who attends Souta’s school, and her buddy, Ash Claude.\n\n(Source: Zenonzard YouTube channel)',
#   'genres': ['Action ', ' Sci-Fi ', ' Drama']},
#  {'cover_title': 'Oda Cinnamon Nobunaga',
#   'cover_studio': 'Studio Signpost',
#   'cover_img': 'https://s4.anilist.co/file/anilistcdn/media/anime/cover/medium/b110613-UVk4CINXaRnX.jpg',
#   'format': 'TV',
#   'duration': '52%',
#   'description': 'The Warring States Period is a time of feuding warlords. Oda Nobunaga, the greatest of them all, is reborn in modern-day Japan... as a shiba-inu! The other generals of the era, too, have also inexplicably been reborn as dogs. Their warring states rivalry will resume at the dog park!\n\n(Source: Crunchyroll)',
#   'genres': ['Comedy']},
#  {'cover_title': 'Kidou Senshi Gundam G40',
#   'cover_studio': 'GEMBA , A-1 Pictures',
#   'cover_img': 'https://s4.anilist.co/file/anilistcdn/media/anime/cover/large/bx114841-Dqc7DaPRdseF.jpg',
#   'format': 'ONA',
#   'duration': '51%',
#   'description': 'U.C. 0079 - A squadron of Zakus from the Principality of Zeon invades a neutral space colony. Amuro Ray reluctantly pilots the Gundam G40 prototype mobile suit to combat the threat, as well as Zeon ace pilot Char Aznable and his custom red Zaku II. (Short animated feature released to promote the High Grade 1/144 scale Gundam G40 model kit and to commemorate the 40th anniversary of the Gundam franchise.)\n\n(Source: Anime News Network)',
#   'genres': ['Action ', ' Mecha ', ' Sci-Fi']},
#  {'cover_title': 'Breakers',
#   'cover_studio': 'ALBACROW , Blaze Studio',
#   'cover_img': 'https://s4.anilist.co/file/anilistcdn/media/anime/cover/large/bx113851-sAw8CmlEXV2t.png',
#   'format': 'TV Short',
#   'duration': '51%',
#   'description': 'The anime centers on para-athletes who all meet an outcast sports scientist named Ren Narita. The anime has four stories about four different sports: wheelchair basketball, track and high jump, goalball, and paralympic swimming.\n\n(Source: Anime News Network)',
#   'genres': ['Sports']},
#  {'cover_title': 'Hatena☆Illusion',
#   'cover_studio': "Children's Playground Entertainment",
#   'cover_img': 'https://s4.anilist.co/file/anilistcdn/media/anime/cover/large/bx98515-sSZiUx4VI0KH.png',
#   'format': 'TV',
#   'duration': '50%',
#   'description': "The series centers on Makoto Shiranui, a boy who travels to Tokyo seeking to become the apprentice of Mamoru Hoshisato, a world-famous magician and friend of his parents. Ever since he had watched a show by Mamoru and his wife Maive, he had dreamed of being a magician. Their daughter Kana (nicknamed Hatena) has been Makoto's friend since childhood. Even though Tokyo has had a rash of burglaries by a beautiful woman thief, Makoto can rest easy as long as Hatena is there. When he arrives at the Hoshisato residence, a haunted mansion, the family butler Jeeves and the maid Emma greet him, and he is reunited with Hatena, only to find out that they don't really get along now.\n\n(Source: Anime News Network)",
#   'genres': ['Comedy ', ' Ecchi ', ' Romance ', ' Supernatural']},
#  {'cover_title': 'Null Peta: Doki~tsu♥ NullNull PetaPeta! Mizugi-darake no o neechan taikai!',
#   'cover_studio': 'Shin-Ei Animation',
#   'cover_img': 'https://s4.anilist.co/file/anilistcdn/media/anime/cover/large/bx113187-mpa6ZxnnBsj8.jpg',
#   'format': 'OVA',
#   'duration': '50%',
#   'description': 'In this bonus episode, Null & Peta find themselves in a trippy multinational pro wrestling match! Can the sisters defeat their foreign alter-egos? Can any of the alternate Petas actually cook!? Will the ref ever put a stop to this chicanery!?!?\n\nAnnounced to be bundled with the Steam game released December 20th, 2019, but later delayed to January 31st, 2020.\n\n(Source: Steam)',
#   'genres': ['Comedy ', ' Sci-Fi ', ' Ecchi ', ' Sports']},
#  {'cover_title': 'Kandagawa JET GIRLS OVA',
#   'cover_studio': 'TNK',
#   'cover_img': 'https://s4.anilist.co/file/anilistcdn/media/anime/cover/medium/b114926-5UWF0mXrrHRV.png',
#   'format': 'OVA',
#   'duration': '50%',
#   'description': 'The racing never ends! Return to the world of Jet Racing and catch up with Rin and Misa in the Kandagawa Jet Girls OVA.\n\n(Source: HIDIVE)',
#   'genres': ['Sports ', ' Ecchi']},
#  {'cover_title': 'Keishicho Tokumu-bu Tokushu Kyoaku-han Taisaku-Shitsu Dai-Nana-ka: Tokunana OVA File 0.5',
#   'cover_studio': 'Anima&Co.',
#   'cover_img': 'https://s4.anilist.co/file/anilistcdn/media/anime/cover/large/bx113864-x75Ts1B8QYjf.jpg',
#   'format': 'OVA',
#   'duration': '50%',
#   'description': 'Episode 0.5 included in the second Blu-ray volume. The episode focuses on Kujaku Nijou, when he first joined the team, one year before the anime begins.',
#   'genres': ['Action ', ' Drama ', ' Psychological']},
#  {'cover_title': 'Knights of the Zodiac: Seitoushi Seiya Part 2',
#   'cover_studio': 'Toei Animation',
#   'cover_img': 'https://s4.anilist.co/file/anilistcdn/media/anime/cover/large/bx114448-nnpndNstYUNF.png',
#   'format': 'ONA',
#   'duration': '49%',
#   'description': 'Part 2 of Knights of the Zodiac: Saint Seiya',
#   'genres': ['Adventure ', ' Fantasy ', ' Sci-Fi']},
#  {'cover_title': 'Hentatsu',
#   'cover_studio': '',
#   'cover_img': 'https://s4.anilist.co/file/anilistcdn/media/anime/cover/large/bx114417-xJtoo8pbK3xz.jpg',
#   'format': 'TV Short',
#   'duration': '45%',
#   'description': 'Hentatsu follows two girls exploring a seemingly abandoned version of Nakano Broadway, a Tokyo shopping mall known for Mandarake and other shops catering to fans of anime and other forms of pop culture.\n\n(Source: Anime News Network)',
#   'genres': ['Adventure ', ' Comedy']},
#  {'cover_title': 'ARP Backstage Pass',
#   'cover_studio': 'Dynamo Pictures',
#   'cover_img': 'https://s4.anilist.co/file/anilistcdn/media/anime/cover/large/bx110615-BPAvwgEZ7iTn.png',
#   'format': 'TV',
#   'duration': '44%',
#   'description': 'ARP (nominally an abbreviation for Artists Republic Production) is a dance vocal group which holds live performances — featuring singing, dancing, and interactive talking with the audience — in real-time using the latest augmented-reality technology. The ikemen (handsome) group members include their de facto leader Shinji, the talented dancer León, and the members of the Rebel Cross duo (designer Daiya and composer/writer Rage).\n\n(Source: Anime News Network)',
#   'genres': ['Music']},
#  {'cover_title': 'Rebirth',
#   'cover_studio': 'LIDENFILMS',
#   'cover_img': 'https://s4.anilist.co/file/anilistcdn/media/anime/cover/large/bx113469-S33qirxVMPdR.jpg',
#   'format': 'TV Short',
#   'duration': '42%',
#   'description': 'The series revolves around a team of 12 high school students who love to play the trading card game Rebirth For You.\n\n(Source: Anime News Network)',
#   'genres': ['Comedy ', ' Slice of Life']},
#  {'cover_title': 'Kyochuu Rettou Movie',
#   'cover_studio': 'Passione',
#   'cover_img': 'https://s4.anilist.co/file/anilistcdn/media/anime/cover/large/bx107880-1gP8jcpVxh2v.jpg',
#   'format': 'Movie',
#   'duration': '38%',
#   'description': "After an airplane crash during a school trip, Oribe Mutsumi and her classmates were stranded on a seemingly deserted island. Mutsumi found the other survivors, and used her wilderness knowledge to help them. She expects that they will be rescued in about three days, which doesn't seem so long to endure. However, she didn't account for the fact that the island is populated with gigantic killer insects. Her knowledge of butterflies, wasps, and more may be the only thing that will help any of her classmates survive to be rescued.\n\n(Source: MangaHelpers)",
#   'genres': ['Action ',
#    ' Drama ',
#    ' Ecchi ',
#    ' Horror ',
#    ' Mystery ',
#    ' Thriller']},
#  {'cover_title': 'SHIROBAKO Movie',
#   'cover_studio': 'P.A. Works',
#   'cover_img': 'https://s4.anilist.co/file/anilistcdn/media/anime/cover/large/bx101574-NlXVoqyDytOS.jpg',
#   'format': 'Movie',
#   'duration': '',
#   'description': 'The story is set four years after the events of the original Shirobako anime. Aoi Miyamori keeps busy dealing with the ordinary troubles in her daily work at Musashino Animation. After a morning meeting, Watanabe talks to Aoi and puts her in charge of a new theatrical anime project for the studio. The project has unexpected problems, and Aoi is unsure if the company can proceed with a theatrical anime with its current state of affairs. While dealing with that anxiety, Aoi meets a new colleague named Kaede Miyai. She and the MusAni team work together to complete the project.\n\n(Source: Anime News Network)',
#   'genres': ['Comedy ', ' Drama ', ' Slice of Life']},
#  {'cover_title': 'Tsuujou Kougeki ga Zentai Kougeki de Ni-kai Kougeki no Okaasan wa Suki desu ka? OVA',
#   'cover_studio': 'J.C. Staff',
#   'cover_img': 'https://s4.anilist.co/file/anilistcdn/media/anime/cover/medium/b110445-0QgiZGhqwXn1.png',
#   'format': 'OVA',
#   'duration': '',
#   'description': "What would you do if you got transported into a video game...with your mom?? That's the dilemma facing high schooler Masato Oosuki, who has been unwittingly thrown into an RPG world with his doting mother close behind as part of a secret government scheme. As an avid gamer, Masato is eager to show off his skills...but that's hard to do when your mom is an insanely overpowered, dual-wielding, multi-target specialist! (Source: Yen Press)",
#   'genres': ['Action ', ' Comedy ', ' Fantasy']},
#  {'cover_title': 'Strike the Blood IV',
#   'cover_studio': 'CONNECT',
#   'cover_img': 'https://s4.anilist.co/file/anilistcdn/media/anime/cover/large/bx112296-YPyJgP91lQK2.png',
#   'format': 'OVA',
#   'duration': '',
#   'description': '',
#   'genres': ['Action ', ' Ecchi ', ' Fantasy ', ' Supernatural']},
#  {'cover_title': 'High School Fleet Movie',
#   'cover_studio': 'A-1 Pictures',
#   'cover_img': 'https://s4.anilist.co/file/anilistcdn/media/anime/cover/large/bx101499-5uIIVuEiCTQq.jpg',
#   'format': 'Movie',
#   'duration': '',
#   'description': 'Announced in April 2018.',
#   'genres': ['Action ', ' Comedy ', ' Slice of Life']},
#  {'cover_title': 'Saezuru Tori wa Habatakanai: The Clouds Gather',
#   'cover_studio': 'GRIZZLY',
#   'cover_img': 'https://s4.anilist.co/file/anilistcdn/media/anime/cover/large/bx109171-gJ51P8kLDxgt.png',
#   'format': 'Movie',
#   'duration': '',
#   'description': "Yashiro is the young leader of Shinseikai and the president of the Shinseikai Enterprise, but like so many powerful men, he leads a double life as a deviant and a masochist. Doumeki Chikara comes to work as a bodyguard for him and, although Yashiro had decided that he would never lay a hand on his own men, he finds there's something about Doumeki that he can't resist. Yashiro makes advances toward Doumeki, but Doumeki has mysterious reasons for denying. Yashiro, who abuses his power just to abuse himself, and Doumeki, who faithfully obeys his every command, begin the tumultuous affair of two men with songs in their hearts and no wings to fly.\n\n(Source: Juné)",
#   'genres': ['Drama']},
#  {'cover_title': 'Nakanohito Genome [Jikkyouchuu]: Knots of Memories',
#   'cover_studio': 'SILVER LINK.',
#   'cover_img': 'https://s4.anilist.co/file/anilistcdn/media/anime/cover/large/bx112177-dzPKFocyvP53.png',
#   'format': 'OVA',
#   'duration': '',
#   'description': 'An original story included with volume 10 of the Nakanohito Genome [Jikkyouchuu] manga.',
#   'genres': ['Comedy ', ' Drama']},
#  {'cover_title': 'Sekaiichi Hatsukoi: Proposal-hen',
#   'cover_studio': '',
#   'cover_img': 'https://s4.anilist.co/file/anilistcdn/media/anime/cover/large/bx111305-GBRFZurlC9e9.jpg',
#   'format': 'Movie',
#   'duration': '',
#   'description': '',
#   'genres': ['Comedy ', ' Drama ', ' Romance']},
#  {'cover_title': 'Chuubyou Gekihatsu Boy OVA',
#   'cover_studio': 'Studio DEEN',
#   'cover_img': 'https://s4.anilist.co/file/anilistcdn/media/anime/cover/large/bx112166-DkjlCbe33Zzo.jpg',
#   'format': 'OVA',
#   'duration': '',
#   'description': 'Unaired 12th episode that is included in the fourth home video release.\n\nThe members of the Hero Club are back in action after their close call with disbandment, and they’ve been tasked with their toughest mission yet! The student council wants them to travel to a distant temple (well, lodge) and assist the guardian (well, caretaker) in his duties. As the club members set off of their quest, Mizuki begins to realize just how accustomed she’s become to her very exciting high school life…\n\n(Source: Sentai Filmworks)',
#   'genres': ['Comedy ', ' Slice of Life']},
#  {'cover_title': 'Haikyuu!! Ningyou Anime',
#   'cover_studio': '',
#   'cover_img': 'https://s4.anilist.co/file/anilistcdn/media/anime/cover/large/bx115217-5Q8RImxnZc9a.png',
#   'format': 'OVA',
#   'duration': '',
#   'description': "A stop-motion anime that will bundle with the 42nd compiled book volume of Haruichi Furudate's Haikyu!! manga. Anime will have 10 short episodes featuring the Karasuno team as puppets.\n\n(Source: Anime News Network)",
#   'genres': ['Sports']},
#  {'cover_title': 'Girls und Panzer: Taiyaki War!',
#   'cover_studio': '',
#   'cover_img': 'https://s4.anilist.co/file/anilistcdn/media/anime/cover/medium/b114052-0MnsA1ydYbVX.jpg',
#   'format': 'OVA',
#   'duration': '',
#   'description': 'OVA included in the Blu-ray/DVD release of the second "Girls und Panzer das Finale" film.',
#   'genres': ['Comedy']},
#  {'cover_title': 'Ongaku',
#   'cover_studio': '',
#   'cover_img': 'https://s4.anilist.co/file/anilistcdn/media/anime/cover/large/bx111944-XKjKbig0DfRr.jpg',
#   'format': 'Movie',
#   'duration': '',
#   'description': 'Anime film adaptation of Hiroyuki Ohashi\'s "Ongaku" manga.\n\nOhashi originally self-published "Ongaku" in 2005, and it tells the story of young delinquents who decide to start a rock band despite never having touched instruments before.\n\n(Source: Anime News Network)',
#   'genres': ['Music']},
#  {'cover_title': 'Digimon Adventure: 20th Memorial Story',
#   'cover_studio': 'Yumeta Company',
#   'cover_img': 'https://s4.anilist.co/file/anilistcdn/media/anime/cover/large/bx115107-GUXZ5XoMfNYW.jpg',
#   'format': 'ONA',
#   'duration': '',
#   'description': 'A series of prequel anime shorts that will tell side stories not shown in Digimon Adventure: Last Evolution Kizuna.\n\nOver ten years have passed since that initial adventure. Sora worries over what she should do with her future. What choice has she ultimately arrived at?\n\n(Source: Toei Animation)',
#   'genres': ['Slice of Life']},
#  {'cover_title': 'Koisuru Asteroid: KiraKira Zoukangou',
#   'cover_studio': '',
#   'cover_img': 'https://s4.anilist.co/file/anilistcdn/media/anime/cover/large/bx114424-1Wu7hiTEbGUL.png',
#   'format': 'ONA',
#   'duration': '',
#   'description': "Series of shorts where Asteroid in Love characters will explain astronomy and geology.\n\nEpisodes streamed weekly for a limited time on KADOKAWA's Youtube channel, later compiled with the Asteroid in Love BD release.",
#   'genres': ['Slice of Life ', ' Comedy']},
#  {'cover_title': 'Hulaing Babies☆Petit',
#   'cover_studio': 'Gaina',
#   'cover_img': 'https://s4.anilist.co/file/anilistcdn/media/anime/cover/large/bx113463-zHcmCnrgiKTK.jpg',
#   'format': 'TV Short',
#   'duration': '',
#   'description': '',
#   'genres': ['Comedy ', ' Slice of Life']},
#  {'cover_title': 'Microphone Soul Spinners: Kotodama Shoujo',
#   'cover_studio': '',
#   'cover_img': 'https://s4.anilist.co/file/anilistcdn/media/anime/cover/large/bx110495-FwS5zNCLLBAx.jpg',
#   'format': 'ONA',
#   'duration': '',
#   'description': 'Part of a new mixed-media project about virtual rap unit.',
#   'genres': ['Music ', ' Comedy']},
#  {'cover_title': 'Tenchi Muyo! Ryo-Ohki 5',
#   'cover_studio': 'AIC',
#   'cover_img': 'https://s4.anilist.co/file/anilistcdn/media/anime/cover/medium/b114442-qyFqcnWnsXRg.jpg',
#   'format': 'OVA',
#   'duration': '',
#   'description': '',
#   'genres': ['Action ', ' Comedy ', ' Sci-Fi']},
#  {'cover_title': 'KING OF PRISM ALL STARS: Prism Show☆Best Ten',
#   'cover_studio': '',
#   'cover_img': 'https://s4.anilist.co/file/anilistcdn/media/anime/cover/large/bx112480-E5eGMMMpi0cw.jpg',
#   'format': 'Movie',
#   'duration': '',
#   'description': '',
#   'genres': ['Music ', ' Sports']},
#  {'cover_title': 'Urashimasakatasen no Nichijou OVA',
#   'cover_studio': 'GAINAX Kyoto',
#   'cover_img': 'https://s4.anilist.co/file/anilistcdn/media/anime/cover/large/bx114196-CiyGipoGtXeq.png',
#   'format': 'OVA',
#   'duration': '',
#   'description': 'Unaired 13th episode released with the DVD.',
#   'genres': ['Comedy ', ' Slice of Life']},
#  {'cover_title': 'Gundam: G no Reconguista II - Bellri Gekishin',
#   'cover_studio': 'Sunrise',
#   'cover_img': 'https://s4.anilist.co/file/anilistcdn/media/anime/cover/large/bx114334-TpuYLurTVs2t.jpg',
#   'format': 'Movie',
#   'duration': '',
#   'description': 'Second Movie in the Gundam: Reconguista in G Movie Recap pentalogy.',
#   'genres': ['Action ', ' Mecha ', ' Sci-Fi']},
#  {'cover_title': 'Ometeotoru≠HERO',
#   'cover_studio': 'Speed',
#   'cover_img': 'https://s4.anilist.co/file/anilistcdn/media/anime/cover/medium/b114948-zarZxhKxW2vP.png',
#   'format': 'Movie',
#   'duration': '',
#   'description': 'In the year 22XX, due to the drastic decrease in the human population, the government starts accepting races from other allied planets. As a result of genetic mixing, new species are born with special powers. A young man named Yuuki learns on his 18th birthday that while his father is a member of the "hero" tribe, his mother is a member of a tribe of beings who can manipulate plants who were supposedly wiped out due to the accelerated mechanization of the planet. As a result, Yuuki holds powers of both tribes, but he questions which side he should help with his powers.\n\n(Source: Anime News Network)',
#   'genres': ['Sci-Fi']},
#  {'cover_title': 'Rebecca',
#   'cover_studio': 'Vega Entertainment',
#   'cover_img': 'https://s4.anilist.co/file/anilistcdn/media/anime/cover/large/bx114945-YimcesTfneqf.jpg',
#   'format': 'Movie',
#   'duration': '',
#   'description': 'Rebecca is a 10-year-old cheerful and energetic girl who is the second of seven children. She lives in a rural town in Maine in the United States at the end of the 19th century. After her father dies, her family descends into poverty, and Rebecca unwillingly goes to live with her aunts Miranda and Jane. Rebecca loves her kind aunt Jane dearly, but her aunt Miranda is naggy and strict.\n\n(Source: Anime News Network)',
#   'genres': ['']},
#  {'cover_title': 'ARP Backstage Pass: Celebrate Good Time - Short Stories',
#   'cover_studio': 'Dynamo Pictures',
#   'cover_img': 'https://s4.anilist.co/file/anilistcdn/media/anime/cover/large/bx116246-5m5ISaTDcIG4.png',
#   'format': 'Special',
#   'duration': '',
#   'description': 'Short Stories of ARP Backstage Pass that describe the secret of the ARP members and everyday life.',
#   'genres': ['Music']},
#  {'cover_title': 'Michiru Rescue!',
#   'cover_studio': 'Yumeta Company',
#   'cover_img': 'https://s4.anilist.co/file/anilistcdn/media/anime/cover/large/bx114946-muGFJUwuiKWV.jpg',
#   'format': 'Movie',
#   'duration': '',
#   'description': 'Four glowing orbs of different color fly through space, chasing after a dark red orb. After a fierce battle, only the blue orb falls to earth, into the room where Michiru is sleeping. But the dark red orb also appears on earth. The orb changes shape into the form of a boy, and starts to illegally raise Mejiro birds. Later, Michiru is at a flea market in a park, when a large flock of Mejiro birds cover the sky, and start attacking people. The yellow, silver, and purple orbs show up and almost manage to calm down the Mejiro, but violence is about to break out again. At that moment, Michiru hears a voice inside her head asking her to save the Mejiro.\n\n(Source: Anime News Network)',
#   'genres': ['']},
#  {'cover_title': 'Marumaru Manul',
#   'cover_studio': 'Kachidoki Studio',
#   'cover_img': 'https://s4.anilist.co/file/anilistcdn/media/anime/cover/large/bx114657-TfKEg5xEN0h1.png',
#   'format': 'TV Short',
#   'duration': '',
#   'description': "The comedy story follows the daily life of a somewhat flippant Pallas's cat or manul named Manul-kun, an orange tabby cat named Chatora-kun, Sukofu-kun, and other cats.\n\n(Source: Anime News Network)",
#   'genres': ['Comedy']},
#  {'cover_title': 'Mobile Suit Gakuen: Kaette Kita G-Reco Koushien',
#   'cover_studio': '',
#   'cover_img': 'https://s4.anilist.co/file/anilistcdn/media/anime/cover/medium/default.jpg',
#   'format': 'Special',
#   'duration': '',
#   'description': 'Shorts bundled with the home video release of the Reconguista in G movie.',
#   'genres': ['Comedy']},
#  {'cover_title': 'Lalalacoco',
#   'cover_studio': 'Studio Comet',
#   'cover_img': 'https://s4.anilist.co/file/anilistcdn/media/anime/cover/large/bx114656-PsHSZZ8dwL6m.jpg',
#   'format': 'TV Short',
#   'duration': '',
#   'description': 'About a girl who loves cute things so much that her daily routine is finding them.',
#   'genres': ['Comedy']}]

# %% [markdown]
# ## Simpan Ke JSON

# %%
import json
f=open('ScrapingAnimelist2.json','w')

# %%
json.dump(winter_anime,f)

# %%
f.close()

# %% [markdown]
# ### Berhenti

# %%
driver.quit()

# %% [markdown]
# # Tugas: Scraping List Manga
#
# Pada Website yang sama lakukan scraping infinite loop pada manga https://anilist.co/search/manga?year=2020%25

# %% [markdown]
# ## Scraping Infinite Loop Manga

# %%
from selenium import webdriver
from selenium.common.exceptions import NoSuchElementException
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.by import By
from selenium.webdriver.support.ui import WebDriverWait
from selenium.common.exceptions import NoSuchElementException
from selenium.webdriver.support import expected_conditions as EC
import json
import time

# %%
driver = webdriver.Chrome()

# %%
url = "https://anilist.co/search/manga?year=2020%25"

# %%
driver.get(url)
print(driver.current_url)
driver.implicitly_wait(30)
# Out:
# https://anilist.co/search/manga?year=2020%25

# %%
def scrollToBottom(driver, timeout):
    last_height = driver.execute_script("return document.body.scrollHeight")

    while True:
        driver.execute_script(
            'window.scrollTo(0, document.body.scrollHeight);')

        WebDriverWait(driver, 10).until(
            EC.presence_of_all_elements_located((By.CLASS_NAME, 'media-card')))

        time.sleep(timeout)

        new_height = driver.execute_script("return document.body.scrollHeight")
        if new_height == last_height:
            break

        last_height = new_height

# %%
scrollToBottom(driver,1)

# %%
result = driver.find_elements_by_class_name('media-card')

# %%
len(result)
# Out:
# 230

# %%
anime_manga = []

# %%
for anime in result:
    cover = anime.find_element_by_class_name("cover")
    extra = anime.find_element_by_class_name("extra").text.split("\n")
    genres = anime.find_element_by_class_name("genres").text
    c_text = cover.text.split("\n")
    anime_manga.append({
        'cover_title': c_text[0],
        'cover_studio': "" if len(c_text) < 2 else c_text[1],
        'cover_img': cover.get_attribute('data-src'),
        'format': extra[0],
        'duration': "" if len(extra) < 2 else extra[1],
        'description': anime.find_element_by_class_name("description").text,
        'genres': genres.split(',')
    })

# %%
anime_manga
# Out:
# [{'cover_title': 'Death Note: Tokubetsu Yomikiri',
#   'cover_studio': '',
#   'cover_img': 'https://s4.anilist.co/file/anilistcdn/media/manga/cover/large/bx115122-HWsbTNeZyoFD.jpg',
#   'format': 'One Shot',
#   'duration': '74%',
#   'description': "The chapter will center on Ryuk's Death Note being brought again to the human world, after the end of the main manga.",
#   'genres': ['Mystery ', ' Supernatural']},
#  {'cover_title': 'Kakkou no Iinazuke',
#   'cover_studio': '',
#   'cover_img': 'https://s4.anilist.co/file/anilistcdn/media/manga/cover/large/bx114383-05Uo5j9nIzf8.png',
#   'format': 'Manga',
#   'duration': '64%',
#   'description': "Kakkou no Iinazuke's story revolves around 2 teenagers who got switched soon after their birth. Hoping to keep both of their biological and adopted children, their parents decided to engage the boy and the girl.",
#   'genres': ['Comedy ', ' Romance']},
#  {'cover_title': 'MASHLE',
#   'cover_studio': '',
#   'cover_img': 'https://s4.anilist.co/file/anilistcdn/media/manga/cover/medium/b114960-td2C5YPWPvre.jpg',
#   'format': 'Manga',
#   'duration': '64%',
#   'description': "This is a world of magic where magic is used for everything. But deep in the forest exists a young man who spends his time training and bulking up. He can't use magic, but he enjoys a peaceful life with his father. But one day, his life is put in danger! Will his muscular body protect him from the magic users who are out to get him? Powerfully trained muscles crush magic as this abnormal magical fantasy begins!\n\n(Source: MANGA Plus)",
#   'genres': ['Action ', ' Fantasy ', ' Comedy']},
#  {'cover_title': 'Undead Unluck',
#   'cover_studio': '',
#   'cover_img': 'https://s4.anilist.co/file/anilistcdn/media/manga/cover/medium/b114791-yQadwc31PjLZ.jpg',
#   'format': 'Manga',
#   'duration': '56%',
#   'description': 'As an UNLUCKY girl prepares to face her death, an UNDEAD who desperately wants to die appears before her! Vicious, violent and buck naked! An unprecedented picaresque hero appears in Shonen Jump!\n\n(Source: MANGA Plus)',
#   'genres': ['Action ', ' Ecchi ', ' Comedy ', ' Supernatural ', ' Sci-Fi']},
#  {'cover_title': 'Majo no Moribito',
#   'cover_studio': '',
#   'cover_img': 'https://s4.anilist.co/file/anilistcdn/media/manga/cover/medium/b115106-Byl1cUytxWkX.jpg',
#   'format': 'Manga',
#   'duration': '55%',
#   'description': "In a world full of Evils, humanity's only hope is the inhuman power of the witches. The city of Berne is on the frontline of the demons and there to protect it is the witch Manasfa and the kingdom's strongest knight Fafner. But what cruel fate awaits these two? A dark fantasy story featuring witches and knights begins now!\n\n(Source: MANGA Plus)",
#   'genres': ['Action ', ' Adventure ', ' Fantasy']},
#  {'cover_title': 'Gantz:E',
#   'cover_studio': '',
#   'cover_img': 'https://s4.anilist.co/file/anilistcdn/media/manga/cover/large/bx114553-bkfnvxQQso5S.jpg',
#   'format': 'Manga',
#   'duration': '',
#   'description': "The manga's story begins when a peasant named Hanbē asks a girl named O-haru for her hand in marriage, but O-haru confesses that she is already thinking of another man named Masakichi from a neighboring village. When Hanbē seeks out Masakichi, he finds that Masakichi possesses a sword and the skills to use it, despite being a peasant.\n\n(Source: Anime News Network)",
#   'genres': ['Action ', ' Drama ', ' Sci-Fi']},
#  {'cover_title': 'Saikin Yatotta Maid ga Ayashii',
#   'cover_studio': '',
#   'cover_img': 'https://s4.anilist.co/file/anilistcdn/media/manga/cover/large/bx114917-XFpzID9gtwxo.jpg',
#   'format': 'Manga',
#   'duration': '',
#   'description': 'The Young Master treads carefully, as his new maid is doing stuff for him that makes him flustered and uncomfortable. What is this teasing woman scheming!? ...Is it love!?',
#   'genres': ['Comedy ', ' Romance ', ' Slice of Life']},
#  {'cover_title': 'Kanojo mo Kanojo',
#   'cover_studio': '',
#   'cover_img': 'https://s4.anilist.co/file/anilistcdn/media/manga/cover/large/bx116266-GUPVU4rYiexi.jpg',
#   'format': 'Manga',
#   'duration': '',
#   'description': "High school boy Naoya gets a confession from Nagisa, a cute and friendly girl. However, Naoya already has a girlfriend, Saki... but Nagisa is too good a catch to let go. Nagisa and Nagoya's goal becomes clear: convince Saki to accept being an item with the two of them. Will she budge?",
#   'genres': ['Comedy ', ' Romance ', ' Slice of Life']},
#  {'cover_title': 'Saihate no Solte',
#   'cover_studio': '',
#   'cover_img': 'https://s4.anilist.co/file/anilistcdn/media/manga/cover/large/bx113461-MbWIlzDy67wg.jpg',
#   'format': 'Manga',
#   'duration': '',
#   'description': 'As a result of a large war, the world was eroded by a magical infection that distorted the time and space around it. Though magic has been outlawed since then, the effects of that war still remain. To uncover all the secrets of the world, "Lucky Solte," begins her adventure.\n\n(Source: MangaUpdates)',
#   'genres': ['Adventure ', ' Fantasy']},
#  {'cover_title': 'Kuro Gal-san ga Kuru!',
#   'cover_studio': '',
#   'cover_img': 'https://s4.anilist.co/file/anilistcdn/media/manga/cover/large/bx115356-jC1RHs29byci.png',
#   'format': 'Manga',
#   'duration': '',
#   'description': 'A beleaguered office worker finds his way to a cafe where he decries the hardships of his routine. In there, a friendly gyaru high schooler notices his lamentations and after hearing him vent out, she cheers him up the "gyaru" way and they exchange contacts. What will become of this unlikely friendship?',
#   'genres': ['Comedy ', ' Ecchi ', ' Romance']},
#  {'cover_title': 'Blattodea',
#   'cover_studio': '',
#   'cover_img': 'https://s4.anilist.co/file/anilistcdn/media/manga/cover/large/bx115056-uNgIdXMwLdOl.jpg',
#   'format': 'Manga',
#   'duration': '',
#   'description': "Alice Fujii still isn't having much fun. She survived an assault of psychotic bug-themed assassins at her school, but all the battles, the truth behind her family, the two betrayals from false friends who ended up dead and the loss of her Kumoito knife-gun took a toll on her mental state. As such, she spends her days alone splitting open the heads of the rapist zombies who overran Japan since the aforementioned incident. The Organization wants to hire her as their new Boss, and elsewhere her allies Gokiburi and Kabutomushi are looking for her. What will become of all this?\n\n(Source: MangaUpdates)",
#   'genres': ['Action ', ' Ecchi']},
#  {'cover_title': 'Dungeon Reset',
#   'cover_studio': '',
#   'cover_img': 'https://s4.anilist.co/file/anilistcdn/media/manga/cover/medium/b116506-phziiF5IJU2U.jpg',
#   'format': 'Manga',
#   'duration': '',
#   'description': "Once it starts up, the dungeon goes through a process called “Reset the Next User”. Why doesn’t this reset process apply to me?! I am the only one left from that endless reset of this dungeon. With simple skills and an overwhelming weapon, Jung-down's game starts inside the dungeon\n\n(Source: Author, translated)",
#   'genres': ['Action ', ' Adventure ', ' Comedy ', ' Fantasy']},
#  {'cover_title': 'Toaru Majutsu no Index: Genesis Testament',
#   'cover_studio': '',
#   'cover_img': 'https://s4.anilist.co/file/anilistcdn/media/manga/cover/large/bx113891-CSUsMVZIaao3.jpg',
#   'format': 'Light Novel',
#   'duration': '',
#   'description': "Science and magic exist side by side in this world.\n\nThis is the peak of the science side with a curriculum for espers, Academy City. In this city where 80% of the population are students, the season has finally come when all residents are excited and fidgety!\n\nIt's Christmas Eve.\n\nAmidst the city showing a cheerful hustle and bustle, ordinary boy who can’t keep up with school, Kamijou Touma, also doesn’t intend to miss this event! He was hard at work in his supplementary lessons...\n\nA backward glance from the default misfortune-prone bastard, the silver-haired sister freeloading in his dormitory, Index, in the heart pounding scene different from the usual, activates a new gluton skill!? While Kamijou tries to desperately stop that, Misaka Mikoto taken in by the Christmas Eve atmosphere appears before him.\n\n(Source: Baka-Tsuki)",
#   'genres': ['Action ', ' Comedy ', ' Fantasy ', ' Sci-Fi']},
#  {'cover_title': 'Kono Healer, Mendokusai',
#   'cover_studio': '',
#   'cover_img': 'https://s4.anilist.co/file/anilistcdn/media/manga/cover/large/bx116091-rursPqDCfRCG.jpg',
#   'format': 'Manga',
#   'duration': '',
#   'description': 'Fantasy adventuring comedy with a dark elf cleric who invested too much on her insulting skills and her companion, the swordsman who has to put up with her antics.\n\n(Source: Kadokawa, translated)',
#   'genres': ['Adventure ', ' Comedy ', ' Fantasy ', ' Slice of Life']},
#  {'cover_title': 'Meika-san wa Oshikorosenai',
#   'cover_studio': '',
#   'cover_img': 'https://s4.anilist.co/file/anilistcdn/media/manga/cover/large/bx115149-eXkHV1iI9jqz.png',
#   'format': 'Manga',
#   'duration': '',
#   'description': "A serialization of the webcomic about a maid, Meika, who can't completely suppress her feelings for her master, Kouta.",
#   'genres': ['Comedy ', ' Romance']},
#  {'cover_title': 'Ore wa Lolicon ja Nai!',
#   'cover_studio': '',
#   'cover_img': 'https://s4.anilist.co/file/anilistcdn/media/manga/cover/large/bx115209-2E8ncIslfD4D.png',
#   'format': 'Manga',
#   'duration': '',
#   'description': "Shouji Osamu is an elementary school teacher fresh out of college about to embark on his first day. At the school gate, he was suddenly hugged by Chise, a girl he doesn't recognize who seems to know him. He later finds out that Chise is a fifth-grade student in his class, and that she lives in the same apartment building as he does. During a late-night rendezvous, he learns that nothing about their encounter is coincidental.",
#   'genres': ['Comedy ', ' Ecchi ', ' Romance']},
#  {'cover_title': 'One Piece Novel Heroines',
#   'cover_studio': '',
#   'cover_img': 'https://s4.anilist.co/file/anilistcdn/media/manga/cover/large/bx113686-2IdSPMbMkr4i.png',
#   'format': 'Light Novel',
#   'duration': '',
#   'description': 'The novel will center on Nami.',
#   'genres': ['Action ', ' Adventure']},
#  {'cover_title': 'Geu Oppadeul-eul Josimhae!',
#   'cover_studio': '',
#   'cover_img': 'https://s4.anilist.co/file/anilistcdn/media/manga/cover/large/bx115302-CCohsBYdFhR0.jpg',
#   'format': 'Manga',
#   'duration': '',
#   'description': "
jpg',
#   'format': 'Manga',
#   'duration': '',
#   'description': 'Ginger Torte and Lerajie Atlanta, both noble daughters of marquesses, are lifelong enemies and rivals.\nWhen Ginger’s fiance, Kishon Mickelson, is stolen by Lerajie, Ginger decides she’s had enough!\nBut one day, Ginger stumbles upon a strange novel - one where Lerajie is the main protagonist, and she is the villainess! She tries her best to ignore it, but when things start playing out just as written in the story, she has no choice but to rely on the novel to change her doomed future as the villainess.\n\n“Exactly what did I do to deserve this fate?! Why did I have to become the villainess?”\n\nEnter the mysterious Prince Ivana, the male lead of the novel. Confined within the depths of the Templar Tower for years by King Astor, he finally sees the light of day when his father passes away. But according to the novel, he’s destined to fall in love with Lerajie, leaving Ginger to wallow in her own misery!\n\n“All I ever did was live life as best I could! But as if stealing my fiance wasn’t enough, now Lerajie is going to claim the male lead?! No way I’ll let that happen!”\nThe “villainess” Ginger, who now knows Prince Ivana’s deepest secret (thanks to the novel), attempts to seduce him with -2% cautiousness and 200% cuteness!\n\n(Source: MangaUpdates)',
#   'genres': ['Fantasy ', ' Romance']},
#  {'cover_title': 'Watashi, Idol Sengen',
#   'cover_studio': '',
#   'cover_img': 'https://s4.anilist.co/file/anilistcdn/media/manga/cover/large/bx114361-x5bDm6tolnnX.jpg',
#   'format': 'Manga',
#   'duration': '',
#   'description': 'A female idol named Mona (Mona Narumi) of the project "Confession Executive Committee -Idol Series-" born from HoneyWorks\' songs is adapted in manga! In contrast to her sister model, Sena Narumi, Mona is an ordinary high school girl. An idol story with HoneyWorks as original and Mogelatte as mangaka!',
#   'genres': ['Romance']},
#  {'cover_title': 'Spy Kyoushitsu',
#   'cover_studio': '',
#   'cover_img': 'https://s4.anilist.co/file/anilistcdn/media/manga/cover/large/bx115935-03GWoEwE1LHQ.jpg',
#   'format': 'Light Novel',
#   'duration': '',
#   'description': 'A world where wars are fought with spies. With a mission success rate of 100%, the remarkable, yet rather difficult to deal with, spy Klaus is being tasked with an almost impossible mission by the agency, harboring an insane 90% chance of failure and death…which for some reason involves seven inexperienced girls?!\n\n(Source: NovelUpdates)',
#   'genres': ['Action ', ' Comedy ', ' Drama']},
#  {'cover_title': 'Maydare Tensei Monogatari: Kono Sekai de Ichiban Warui Majo',
#   'cover_studio': '',
#   'cover_img': 'https://s4.anilist.co/file/anilistcdn/media/manga/cover/large/bx115979-KiK0xnv5e6Ce.jpg',
#   'format': 'Manga',
#   'duration': '',
# ...
#   'genres': ['Mahou Shoujo']},
#  {'cover_title': 'Ramen Saiyuuki',
#   'cover_studio': '',
#   'cover_img': 'https://s4.anilist.co/file/anilistcdn/media/manga/cover/large/bx116527-Pv55hvJlOly7.jpg',
#   'format': 'Manga',
#   'duration': '',
#   'description': '',
#   'genres': ['Drama ', ' Slice of Life']},
#  {'cover_title': 'HiGH&LOW THE WORST: Housen Gakuen Nisshi',
#   'cover_studio': '',
#   'cover_img': 'https://s4.anilist.co/file/anilistcdn/media/manga/cover/large/bx116528-SBRUpU3hb69u.png',
#   'format': 'Manga',
#   'duration': '',
#   'description': '',
#   'genres': ['Action ', ' Comedy ', ' Drama']},
#  {'cover_title': 'Kaki no Hanashi',
#   'cover_studio': '',
#   'cover_img': 'https://s4.anilist.co/file/anilistcdn/media/manga/cover/large/bx116274-xdS4udXIxkPK.png',
#   'format': 'One Shot',
#   'duration': '',
#   'description': 'The one-shot follows a married couple who live in a high-rise apartment complex, and their neighbor who moves in.',
#   'genres': ['Drama ', ' Slice of Life ', ' Romance']},
#  {'cover_title': 'Liaison: Kodomo no Kokoro Shinryousho',
#   'cover_studio': '',
#   'cover_img': 'https://s4.anilist.co/file/anilistcdn/media/manga/cover/large/bx116538-FJOgL6jteWiT.jpg',
#   'format': 'Manga',
#   'duration': '',
#   'description': '',
#   'genres': ['Drama ', ' Comedy ', ' Slice of Life']},
#  {'cover_title': 'Mitsuba-kun wa Aniyome-san to.',
#   'cover_studio': '',
#   'cover_img': 'https://s4.anilist.co/file/anilistcdn/media/manga/cover/medium/b116308-gNd6XIQAtfwk.png',
#   'format': 'Manga',
#   'duration': '',
#   'description': "The manga follows the carefree life and delicate relationship between a nine-year-old brother-in-law and his older brother's 21-year-old wife.\n\n(Source: Anime News Network)",
#   'genres': ['Comedy ', ' Slice of Life']},
#  {'cover_title': 'Sakanaya no Musume',
#   'cover_studio': '',
#   'cover_img': 'https://s4.anilist.co/file/anilistcdn/media/manga/cover/large/bx116068-s5O9piGk6Nil.png',
#   'format': 'One Shot',
#   'duration': '',
#   'description': '',
#   'genres': ['Drama ', ' Fantasy ', ' Sci-Fi ', ' Slice of Life']},
#  {'cover_title': 'Oshiri Dandy The Young',
#   'cover_studio': '',
#   'cover_img': 'https://s4.anilist.co/file/anilistcdn/media/manga/cover/large/bx115081-pVQ1PAsFBQmL.jpg',
#   'format': 'Manga',
#   'duration': '',
#   'description': "This manga is a prequel centered on the past of Dandy, who is Oshiri's father",
#   'genres': ['Action ', ' Adventure ', ' Comedy']},
#  {'cover_title': 'Shadow Newt: Saisei Nouryoku de Mezasu S Kyuu Saikyou!',
#   'cover_studio': '',
#   'cover_img': 'https://s4.anilist.co/file/anilistcdn/media/manga/cover/medium/b115614-gxfVKKoJtFEh.png',
#   'format': 'Manga',
#   'duration': '',
#   'description': '

#   'cover_studio': '',
#   'cover_img': 'https://s4.anilist.co/file/anilistcdn/media/manga/cover/large/bx116463-NPfh9vXaByVS.jpg',
#   'format': 'Manga',
#   'duration': '',
#   'description': '',
#   'genres': ['Drama ', ' Horror ', ' Psychological']},
#  {'cover_title': 'Shiro to Kuro: Black & White',
#   'cover_studio': '',
#   'cover_img': 'https://s4.anilist.co/file/anilistcdn/media/manga/cover/medium/b116737-AKc5nXEQIqlc.jpg',
#   'format': 'Manga',
#   'duration': '',
#   'description': '',
#   'genres': ['Romance ', ' Psychological']},
#  {'cover_title': 'Gurazeni: Natsunosuke no Seishun',
#   'cover_studio': '',
#   'cover_img': 'https://s4.anilist.co/file/anilistcdn/media/manga/cover/large/bx116523-F6htDZwO2iLi.jpg',
#   'format': 'Manga',
#   'duration': '',
#   'description': '',
#   'genres': ['Sports']},
#  {'cover_title': 'Futari Gurashi',
#   'cover_studio': '',
#   'cover_img': 'https://s4.anilist.co/file/anilistcdn/media/manga/cover/large/bx116531-KSyKfAM8QfzQ.jpg',
#   'format': 'Manga',
#   'duration': '',
#   'description': '',
#   'genres': ['Drama ', ' Slice of Life']},
#  {'cover_title': '(Title to be Announced)',
#   'cover_studio': '',
#   'cover_img': 'https://s4.anilist.co/file/anilistcdn/media/manga/cover/medium/b112436-ymXqv9epqfpJ.png',
#   'format': 'Manga',
#   'duration': '',
#   'description': "Serialization of Yuuki Ichihara's new work - announced 2019/10/08 - presently untitled.\nAnnouncement Link",
#   'genres': ['']},
#  {'cover_title': 'Bakumatsu Rock Urotama',
#   'cover_studio': '',
#   'cover_img': 'https://s4.anilist.co/file/anilistcdn/media/manga/cover/large/bx114999-GAlN9cb7604V.jpg',
#   'format': 'Manga',
#   'duration': '',
#   'description': '',
#   'genres': ['Action ', ' Music']},
#  {'cover_title': 'Sorairo Memorial',
#   'cover_studio': '',
#   'cover_img': 'https://s4.anilist.co/file/anilistcdn/media/manga/cover/medium/b114267-P2hxv8MOrAHF.png',
#   'format': 'Manga',
#   'duration': '',
#   'description': 'The story follows Sora, whose fate greatly changes when she meets a mysterious boy at her house, which is an old shrine.\n\n(Source: Anime News Network)',
#   'genres': ['Slice of Life']},
#  {'cover_title': 'Mahou no Hyokko',
#   'cover_studio': '',
#   'cover_img': 'https://s4.anilist.co/file/anilistcdn/media/manga/cover/large/bx116350-e1hpb1CuCCPk.jpg',
#   'format': 'One Shot',
#   'duration': '',
#   'description': '',
#   'genres': ['Comedy ', ' Fantasy']},
#  {'cover_title': 'Omocha to Ocha wo',
#   'cover_studio': '',
#   'cover_img': 'https://s4.anilist.co/file/anilistcdn/media/manga/cover/large/bx116608-tJHzTOCnYkDT.png',
#   'format': 'Manga',
#   'duration': '',
#   'description': '',
#   'genres': ['Slice of Life ', ' Supernatural']},
#  {'cover_title': 'Jack Fox: Kitsune Otoko to Koutetsu Onna',
#   'cover_studio': '',
#   'cover_img': 'https://s4.anilist.co/file/anilistcdn/media/manga/cover/medium/b115616-mmGoh6Yk5Ihf.png',
#   'format': 'Manga',
#   'duration': '',
#   'description': '',
#   'genres': ['Action ', ' Adventure ', ' Drama ', ' Fantasy ', ' Comedy']},
#  {'cover_title': 'Shutsugeki! Kissa Arpeggio',
#   'cover_studio': '',
#   'cover_img': 'https://s4.anilist.co/file/anilistcdn/media/manga/cover/medium/b114852-ItHcm7qRJBir.png',
#   'format': 'Manga',
#   'duration': '',
#   'description': '',
#   'genres': ['Comedy ', ' Slice of Life']},
#  {'cover_title': 'Mijikai Oudanhodou mo Matsu Type no Chuugakusei',
#   'cover_studio': '',
#   'cover_img': 'https://s4.anilist.co/file/anilistcdn/media/manga/cover/large/bx115622-vrbvHbDE1Jf4.jpg',
#   'format': 'Manga',
#   'duration': '',
#   'description': '',
#   'genres': ['Comedy']},
#  {'cover_title': 'Kiniro Mosaic: Best wishes.',
#   'cover_studio': '',
#   'cover_img': 'https://s4.anilist.co/file/anilistcdn/media/manga/cover/large/bx116694-Dc2ppvEAdLQ3.jpg',
#   'format': 'Manga',
#   'duration': '',
#   'description': '',
#   'genres': ['Comedy ', ' Slice of Life']},
#  {'cover_title': 'Sora no Namida',
#   'cover_studio': '',
#   'cover_img': 'https://s4.anilist.co/file/anilistcdn/media/manga/cover/large/bx115163-NnQTBoOqjf73.jpg',
#   'format': 'One Shot',
#   'duration': '',
#   'description': '',
#   'genres': ['Comedy ', ' Drama ', ' Supernatural ', ' Romance']},
#  {'cover_title': 'Datte tada no Onnanoko Nande',
#   'cover_studio': '',
#   'cover_img': 'https://s4.anilist.co/file/anilistcdn/media/manga/cover/medium/b114655-sImjCBGLWz0J.jpg',
#   'format': 'One Shot',
#   'duration': '',
#   'description': '',
#   'genres': ['']},
#  {'cover_title': 'Misty Night',
#   'cover_studio': '',
#   'cover_img': 'https://s4.anilist.co/file/anilistcdn/media/manga/cover/medium/b115284-E5MKoBt1i306.jpg',
#   'format': 'One Shot',
#   'duration': '',
#   'description': '',
#   'genres': ['Romance']},
#  {'cover_title': 'Dekiai Royale',
#   'cover_studio': '',
#   'cover_img': 'https://s4.anilist.co/file/anilistcdn/media/manga/cover/large/bx114271-3EUqdcg6oUGp.png',
#   'format': 'Manga',
#   'duration': '',
#   'description': "Kagura Itsuki is the demon king's daughter. She spends every day having fun with her three childhood friends: a werewolf, vampire, and oni. On her 14th birthday, the princess receives a surprising present...\n\n(Source: MangaUpdates)",
#   'genres': ['Comedy ', ' Supernatural']},
#  {'cover_title': 'Meikyuu Biyori',
#   'cover_studio': '',
#   'cover_img': 'https://s4.anilist.co/file/anilistcdn/media/manga/cover/large/bx114365-PstR6n9l62vX.jpg',
#   'format': 'Manga',
#   'duration': '',
#   'description': 'The story is about Hinata and her friends, the only people who know about a secret pool. Where they are playing, they find a suspicious attache case at the bottom of the water. The manga is a story of the maze-like, mixed-up world of youthful, lazy days.\n\n(Source: Anime News Network)',
#   'genres': ['']}]

# %% [markdown]
# ### Simpan Ke JSON

# %%
import json
f=open('ScrapingAnimelist3.json','w')

# %%
json.dump(anime_manga,f)

# %%
f.close()

# %% [markdown]
# ### Berhenti

# %%
driver.quit()
